# %% [markdown]
# ##DATASET REPORT COMPILER - (DRAFT) - Work In Progress

# %% [markdown]
# #This notebook is to compile and analyze a dataset, and generate a report based on the findings. The notebook aim is to contain code for importing and cleaning the data, as well as performing any necessary transformations or manipulations. if applicable, perform various analyses, such as descriptive statistics, data visualization, and modelling.
#
# #The final output of the notebook will be a comprehensive report that summarizes the insights and conclusions drawn from the dataset. The report may include charts, graphs, and other visual aids to help communicate the findings effectively. The overall goal of the notebook is to provide a clear and concise understanding of the dataset and its implications for the intended audience.

# %% [markdown]
# FOLLOW THE STEPS BELOW:

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#url = "https://raw.githubusercontent.com/Chameleon-company/EVCFLO/main/datasets/T1_2023/Electric%20Vehicle%20Charging%20Stations%20NSW%20-%2020211207/Electric%20Vehicle%20Charging%20Stations%20NSW%20-%2020211207.csv"

url=""

def load_data(url=None):
    if url is None:
        url = input("Please enter the URL to the CSV file: ")
    
    data = pd.read_csv(url)
    return data

data = load_data()

# %%
print("This dataset has", data.shape[0], "rows and", data.shape[1], "columns.")

print("Columns & data types in the dataset:")
print(data.dtypes)
# Out:
# This dataset has 58 rows and 8 columns.
# Columns & data types in the dataset:
# Organisation_Name            object
# Service_Station_Location     object
# Latitude                    float64
# Longitude                   float64
# Unnamed: 4                  float64
# Unnamed: 5                  float64
# Unnamed: 6                  float64
# Unnamed: 7                  float64
# dtype: object

# %%
for col in data.columns:
    if data[col].dtype == 'object':
        print(f"{col}: {data[col].unique()}")
    elif data[col].dtype == 'float64':
        # Remove NaN values from column
        col_data = data[col].dropna()
        # Create histogram plot
        plt.hist(col_data)
        plt.title(col)
        plt.show()

        #Add or replace sections of these code to to generate more features in final (In progress)
# Out:
# Organisation_Name: ['NATIONAL ROADS AND MOTORISTS ASSOCIATION LIMITED'
#  "NATIONAL ROADS AND MOTORISTS' ASSOCIATION LIMITED"
#  'Place Management NSW' 'Srinivasa Fuels PTY LTD'
#  'Telsa Motors Australia, PTY LTD' 'WILSON PARKING AUSTRALIA 1992 PTY LTD']
# Service_Station_Location: ['9 Murray Rose,SYDNEY OLYMPIC PARK NSW 2127,AUSTRALIA'
#  '76 Cowper St,WALLSEND NSW 2287,AUSTRALIA'
#  'Hunter Valley Gardens 2090 Broke Road,POKOLBIN NSW 2320,AUSTRALIA'
#  'Cnr Hume Highway & Bessemer Street,MITTAGONG NSW 2575,AUSTRALIA'
#  '140 Queen St,BERRY NSW 2535,AUSTRALIA'
#  '31 Twynam St,NARRANDERA NSW 2700,AUSTRALIA'
#  '88 Lovell St,YOUNG NSW 2594,AUSTRALIA'
#  '13-17 Shire St,WEST WYALONG NSW 2671,AUSTRALIA'
#  '1 Kendall Avenue,BATHURST NSW 2795,AUSTRALIA'
#  '27-29 Dalton Street,PARKES NSW 2870,AUSTRALIA'
#  '76 Wingewarra Street,DUBBO NSW 2830,AUSTRALIA'
#  '37 Nabiac St,NABIAC NSW 2312,AUSTRALIA'
#  '2 Kable Avenue,TAMWORTH NSW 2340,AUSTRALIA'
#  '2a Beach Road,BATEMANS BAY NSW 2536,AUSTRALIA'
#  'Via Lords Pl (charger behind Orange Civic Theatre),ORANGE NSW 2800,AUSTRALIA'
