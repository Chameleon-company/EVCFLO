# %% [markdown]
# ## EVCS - Interactive Map Development - Melbourne and Geelong Region

# %% [markdown]
# In this analysis, we will built an Interactive Map that provides indications of exisiting EVCS locations, as well as the possible future charging sites. Techniques used in this analysis is based on the EVCS location datasets of Melbourne and Geelong, and Melbourne off street parking lot location dataset.

# %%
import pandas as pd
import folium
from geopy.distance import distance
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ### Dataset Preparation

# %%
stations = pd.read_csv("Greater_Melbourne_and_Geelong.csv")
stations.head().T
# Out:
#                                                                             0  \
# name                                                     Geelong Supercharger
# address                     470-510 Princes Hwy, Geelong, VIC, Australia, ...
# longitude                                                             144.382
# latitude                                                             -38.0652
# description                                                               NaN
# parking                                                                   NaN
# pricing                                                                   NaN
# contact                                                           61280152834
# networks                                                     ['Supercharger']
# total_plugs                                                                 6
# renewable_power_supply                                                    NaN
# Plugs_CCS_SAE                                                               0
# Plugs_CHAdeMO                                                               0
# Plugs_Caravan_Mains_Socket                                                  0
# Plugs_J1772                                                                 0
# Plugs_Tesla                                                                 6
# Plugs_Three_Phase                                                           0
# Plugs_Commando                                                            NaN
# Plugs_Type2                                                                 0
# Plugs_Wall_AU_NZ                                                            0
# Plugs_Other                                                               NaN
# power_outputs_kw                                                      [250.0]
# source                                                       PlugShare_Scrape
# source_date                                                        20/08/2022
#
#                                                                            1  \
# name                                         Penguin Parade Visitor's Centre
# address                     995 Ventnor Road Summerlands VIC 3922, Australia
# longitude                                                            145.148
# latitude                                                            -38.5055
# description                                                              NaN
# parking                                                                  NaN
# pricing                                                                  NaN
# contact                                                                  NaN
# networks                                                   ['Non-networked']
# total_plugs                                                                2
# renewable_power_supply                                                   NaN
# Plugs_CCS_SAE                                                              1
# Plugs_CHAdeMO                                                              1
# Plugs_Caravan_Mains_Socket                                                 0
# Plugs_J1772                                                                0
# Plugs_Tesla                                                                0
# Plugs_Three_Phase                                                          0
# Plugs_Commando                                                           NaN
# Plugs_Type2                                                                0
# Plugs_Wall_AU_NZ                                                           0
# Plugs_Other                                                              NaN
# power_outputs_kw                                                      [25.0]
# source                                                      PlugShare_Scrape
# source_date                                                       20/08/2022
#
#                                                                             2  \
# name                                                  Mornington Supercharger
# address                     75 Mornington-Tyabb Rd, Mornington VIC 3931, A...
# longitude                                                             145.051
# latitude                                                             -38.2343
# description                                                               NaN
# parking                                                                   NaN
# pricing                                                                   NaN
# contact                                                           61280152834
# networks                                                     ['Supercharger']
# total_plugs                                                                 6
# renewable_power_supply                                                    NaN
# Plugs_CCS_SAE                                                               0
# Plugs_CHAdeMO                                                               0
# Plugs_Caravan_Mains_Socket                                                  0
# Plugs_J1772                                                                 0
# Plugs_Tesla                                                                 6
# Plugs_Three_Phase                                                           0
# Plugs_Commando                                                            NaN
# Plugs_Type2                                                                 0
# Plugs_Wall_AU_NZ                                                            0
# Plugs_Other                                                               NaN
# power_outputs_kw                                                      [250.0]
# source                                                       PlugShare_Scrape
# source_date                                                        20/08/2022
#
#                                                                             3  \
# name                                Kingston Village Square (DC Fast Charger)
# address                     Kingston Village Square, Grubb Rd, Ocean Grove...
# longitude                                                              144.54
# latitude                                                             -38.2467
# description                                                               NaN
# parking                                                                   NaN
# pricing                                                                   NaN
# contact                                                            1300518038
# networks                                                        ['Chargefox']
# total_plugs                                                                 4
# renewable_power_supply                                                    NaN
# Plugs_CCS_SAE                                                               1
# Plugs_CHAdeMO                                                               1
# Plugs_Caravan_Mains_Socket                                                  0
# Plugs_J1772                                                                 0
# Plugs_Tesla                                                                 0
# Plugs_Three_Phase                                                           0
# Plugs_Commando                                                            NaN
# Plugs_Type2                                                                 2
# Plugs_Wall_AU_NZ                                                            0
# Plugs_Other                                                               NaN
# power_outputs_kw                                            [50.0, 'unknown']
# source                                                       PlugShare_Scrape
# source_date                                                        20/08/2022
#
#                                                                             4
# name                                         BIG4 Phillip Island Caravan Park
# address                     24 Old Bridge Drive, Newhaven VIC 3925, Australia
# longitude                                                             145.356
# latitude                                                             -38.5168
# description                                                               NaN
# parking                                                                   NaN
# pricing                                                                   NaN
# contact                                                            0359567227
# networks                                                    ['Non-networked']
# total_plugs                                                                 2
# renewable_power_supply                                                    NaN
# Plugs_CCS_SAE                                                               0
# Plugs_CHAdeMO                                                               0
# Plugs_Caravan_Mains_Socket                                                  1
# Plugs_J1772                                                                 0
# Plugs_Tesla                                                                 0
# Plugs_Three_Phase                                                           0
# Plugs_Commando                                                            NaN
# Plugs_Type2                                                                 0
# Plugs_Wall_AU_NZ                                                            1
# Plugs_Other                                                               NaN
# power_outputs_kw                                                  ['unknown']
# source                                                       PlugShare_Scrape
# source_date                                                        20/08/2022

# %%
# Latitude and longitude values passed in from dataset
my_map = folium.Map(location = [-37.884254, 144.736465], width = 1000, height = 600)

for _, station in stations.iterrows():
    folium.Marker(location = [station["latitude"], station["longitude"]],
                 popup = station["name"],
                 tooltip = station["name"]).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_f19a9f1c380b01a5013904e07162ac49 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_f19a9f1c380b01a5013904e07162ac49&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_f19a9f1c380b01a5013904e07162ac49 = L.map(
#                 &quot;map_f19a9f1c380b01a5013904e07162ac49&quot;,
#                 {
#                     center: [-37.884254, 144.736465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_42d2db8ff0f94bbe6919650da0516eeb = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_f19a9f1c380b01a5013904e07162ac49);
#
#
#             var marker_b46639ab90795f8d413dcad4400e6827 = L.marker(
#                 [-38.065191999999996, 144.382451],
#                 {}
#             ).addTo(map_f19a9f1c380b01a5013904e07162ac49);
#
#
#         var popup_19ab9990b1a9a1971fc3d23a372cdd45 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_7e4920590a9e528d4981f35357453732 = $(`&lt;div id=&quot;html_7e4920590a9e528d4981f35357453732&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Geelong Supercharger&lt;/div&gt;`)[0];
#             popup_19ab9990b1a9a1971fc3d23a372cdd45.setContent(html_7e4920590a9e528d4981f35357453732);
#
#
#         marker_b46639ab90795f8d413dcad4400e6827.bindPopup(popup_19ab9990b1a9a1971fc3d23a372cdd45)
#         ;
#
#
#
#
#             marker_b46639ab90795f8d413dcad4400e6827.bindTooltip(
#                 `&lt;div&gt;
#                      Geelong Supercharger
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_076210af6992dff6329c0f5ee8ce81a7 = L.marker(
#                 [-38.505496, 145.148488],
#                 {}
#             ).addTo(map_f19a9f1c380b01a5013904e07162ac49);
#
#
#         var popup_a1d8b9b29cc9db0d9cf408b700e470c2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_0c81dbdfd416fe800c27fc6b183d190d = $(`&lt;div id=&quot;html_0c81dbdfd416fe800c27fc6b183d190d&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Penguin Parade Visitor&#x27;s Centre&lt;/div&gt;`)[0];
#             popup_a1d8b9b29cc9db0d9cf408b700e470c2.setContent(html_0c81dbdfd416fe800c27fc6b183d190d);
#
#
#         marker_076210af6992dff6329c0f5ee8ce81a7.bindPopup(popup_a1d8b9b29cc9db0d9cf408b700e470c2)
#         ;
#
#
#
#
#             marker_076210af6992dff6329c0f5ee8ce81a7.bindTooltip(
#                 `&lt;div&gt;
#                      Penguin Parade Visitor&#x27;s Centre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_36fc7c362e9fc56a1a58ab35c39dc054 = L.marker(
#                 [-38.234305, 145.051085],
#                 {}
#             ).addTo(map_f19a9f1c380b01a5013904e07162ac49);
#
#
#         var popup_b5c167a54e7a13bfcef4f3ba24adb2e1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_d436e641292aa23b1c6d230e9f128182 = $(`&lt;div id=&quot;html_d436e641292aa23b1c6d230e9f128182&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mornington Supercharger&lt;/div&gt;`)[0];
#             popup_b5c167a54e7a13bfcef4f3ba24adb2e1.setContent(html_d436e641292aa23b1c6d230e9f128182);
#
#
#         marker_36fc7c362e9fc56a1a58ab35c39dc054.bindPopup(popup_b5c167a54e7a13bfcef4f3ba24adb2e1)
#         ;
#
#
#
#
#             marker_36fc7c362e9fc56a1a58ab35c39dc054.bindTooltip(
#                 `&lt;div&gt;
#                      Mornington Supercharger
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fc5d6ffbdfddd505d28d4e9f52391f8d = L.marker(
#                 [-38.246677000000005, 144.540122],
#                 {}
#             ).addTo(map_f19a9f1c380b01a5013904e07162ac49);
#
#
#         var popup_daa09ccf8a406ae3145c74cf95ffa1c3 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_00b57bc863d5c1f96f3fad26c9fc57b5 = $(`&lt;div id=&quot;html_00b57bc863d5c1f96f3fad26c9fc57b5&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Kingston Village Square (DC Fast Charger)&lt;/div&gt;`)[0];
#             popup_daa09ccf8a406ae3145c74cf95ffa1c3.setContent(html_00b57bc863d5c1f96f3fad26c9fc57b5);
#
#
#         marker_fc5d6ffbdfddd505d28d4e9f52391f8d.bindPopup(popup_daa09ccf8a406ae3145c74cf95ffa1c3)
#         ;
#
#
#
#
#             marker_fc5d6ffbdfddd505d28d4e9f52391f8d.bindTooltip(
#                 `&lt;div&gt;
#                      Kingston Village Square (DC Fast Charger)
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_22b846884c7053487af31f670be60b0c = L.marker(
#                 [-38.51

# %% [markdown]
# ### Clustered Map

# %%
# Clustering existing EVCSs
from folium import Marker
from folium.plugins import MarkerCluster

my_map = folium.Map(location = [-37.884254, 144.736465], width = 1000, height = 600)
mc = MarkerCluster()

for _, station in stations.iterrows():
    mc.add_child(Marker(location = [station["latitude"], station["longitude"]],
                 popup = station["name"], tooltip = station["name"]))

my_map.add_child(mc)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_b2c262b974357e70a1286a036f64bb0b {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/leaflet.markercluster.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/leaflet.markercluster/1.1.0/MarkerCluster.Default.css&quot;/&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_b2c262b974357e70a1286a036f64bb0b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_b2c262b974357e70a1286a036f64bb0b = L.map(
#                 &quot;map_b2c262b974357e70a1286a036f64bb0b&quot;,
#                 {
#                     center: [-37.884254, 144.736465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_a658752db5cb44c403a9ae3c537ddcc4 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_b2c262b974357e70a1286a036f64bb0b);
#
#
#             var marker_cluster_c0107f5be06137a9703a8246852e3d88 = L.markerClusterGroup(
#                 {}
#             );
#             map_b2c262b974357e70a1286a036f64bb0b.addLayer(marker_cluster_c0107f5be06137a9703a8246852e3d88);
#
#
#             var marker_8b70dd593f835a100bd550d98bef191d = L.marker(
#                 [-38.065191999999996, 144.382451],
#                 {}
#             ).addTo(marker_cluster_c0107f5be06137a9703a8246852e3d88);
#
#
#         var popup_f7fc320fd30179a4e4706adc95b33545 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_71aa96c26a223706b4c71f12b0cd6177 = $(`&lt;div id=&quot;html_71aa96c26a223706b4c71f12b0cd6177&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Geelong Supercharger&lt;/div&gt;`)[0];
#             popup_f7fc320fd30179a4e4706adc95b33545.setContent(html_71aa96c26a223706b4c71f12b0cd6177);
#
#
#         marker_8b70dd593f835a100bd550d98bef191d.bindPopup(popup_f7fc320fd30179a4e4706adc95b33545)
#         ;
#
#
#
#
#             marker_8b70dd593f835a100bd550d98bef191d.bindTooltip(
#                 `&lt;div&gt;
#                      Geelong Supercharger
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_0ea4b06221aa67f8d61bcf4dbc0cabd7 = L.marker(
#                 [-38.505496, 145.148488],
#                 {}
#             ).addTo(marker_cluster_c0107f5be06137a9703a8246852e3d88);
#
#
#         var popup_6f9ec79f8cc438228128fc0242c898e0 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_dc13648bb5a1ec26f4f0aecd941dffcb = $(`&lt;div id=&quot;html_dc13648bb5a1ec26f4f0aecd941dffcb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Penguin Parade Visitor&#x27;s Centre&lt;/div&gt;`)[0];
#             popup_6f9ec79f8cc438228128fc0242c898e0.setContent(html_dc13648bb5a1ec26f4f0aecd941dffcb);
#
#
#         marker_0ea4b06221aa67f8d61bcf4dbc0cabd7.bindPopup(popup_6f9ec79f8cc438228128fc0242c898e0)
#         ;
#
#
#
#
#             marker_0ea4b06221aa67f8d61bcf4dbc0cabd7.bindTooltip(
#                 `&lt;div&gt;
#                      Penguin Parade Visitor&#x27;s Centre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_fa438f8d92def9cb39cf376c9e916bd5 = L.marker(
#                 [-38.234305, 145.051085],
#                 {}
#             ).addTo(marker_cluster_c0107f5be06137a9703a8246852e3d88);
#
#
#         var popup_44544177f63eb1d1f3ca3bee0f9ebeb2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_46dbf0e68265f2bb33657c9bd9dfdfff = $(`&lt;div id=&quot;html_46dbf0e68265f2bb33657c9bd9dfdfff&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Mornington Supercharger&lt;/div&gt;`)[0];
#             popup_44544177f63eb1d1f3ca3bee0f9ebeb2.setContent(html_46dbf0e68265f2bb33657c9bd9dfdfff);
#
#
#         marker_fa438f8d92def9cb39cf376c9e916bd5.bindPopup(popup_44544177f63eb1d1f3ca3bee0f9ebeb2)
#         ;
#
#
#
#
#             marker_fa438f8d92def9cb39cf376c9e916bd5.bindTooltip(
#                 `&lt;div&gt;
#                      Mornington Supercharger
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_47685a002227f7f062affe7f64e92521 = L.marker(
#                 [-38.246677000000005, 144.540122],
#                 {}
#             ).addTo(marker_cluster_c0107f5be06137a9703a8246852e3d88);
#
#
#         var popup_631cecfc86608ceace58779dfcf4cc76 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_f05dbec4d637ca04d9a2b54f32a93d1b = $(`&lt;div id=&quot;html_f05dbec4d63

# %% [markdown]
# ### Map Distinguishing lonely EVCSs

# %%
# Create coordinate list for storing distance between stations
coordinates = []
for _, station in stations.iterrows():
    location = [[station["latitude"], station["longitude"]]]
    coordinates += location

# %%
# Interate through each nearby station by the distance 
stations["whether_evcs"] = ""

for i in range(len(coordinates)):
    location1 = coordinates[i]
    evcs_counts = 0
    for j in range(len(coordinates)):       
        if i == j:
            pass
        elif distance(coordinates[j], location1) < 5: # Maximum 5km from given EVCS
            evcs_counts += 1
        else:
            evcs_counts += 0
            
    if evcs_counts > 0:
        stations["whether_evcs"].iloc[i] = "no" # No - no extra stations needed
    else:
        stations["whether_evcs"].iloc[i] = "yes" # Yes - additional stations needed

stations.head()
# Out:
#                                         name  \
# 0                       Geelong Supercharger
# 1            Penguin Parade Visitor's Centre
# 2                    Mornington Supercharger
# 3  Kingston Village Square (DC Fast Charger)
# 4           BIG4 Phillip Island Caravan Park
#
#                                              address   longitude   latitude  \
# 0  470-510 Princes Hwy, Geelong, VIC, Australia, ...  144.382451 -38.065192
# 1   995 Ventnor Road Summerlands VIC 3922, Australia  145.148488 -38.505496
# 2  75 Mornington-Tyabb Rd, Mornington VIC 3931, A...  145.051085 -38.234305
# 3  Kingston Village Square, Grubb Rd, Ocean Grove...  144.540122 -38.246677
# 4  24 Old Bridge Drive, Newhaven VIC 3925, Australia  145.356460 -38.516829
#
#    description  parking  pricing      contact           networks  total_plugs  \
# 0          NaN      NaN      NaN  61280152834   ['Supercharger']            6
# 1          NaN      NaN      NaN          NaN  ['Non-networked']            2
# 2          NaN      NaN      NaN  61280152834   ['Supercharger']            6
# 3          NaN      NaN      NaN   1300518038      ['Chargefox']            4
# 4          NaN      NaN      NaN   0359567227  ['Non-networked']            2
#
#    ...  Plugs_Tesla  Plugs_Three_Phase  Plugs_Commando  Plugs_Type2  \
# 0  ...            6                  0             NaN            0
# 1  ...            0                  0             NaN            0
# 2  ...            6                  0             NaN            0
# 3  ...            0                  0             NaN            2
# 4  ...            0                  0             NaN            0
#
#    Plugs_Wall_AU_NZ  Plugs_Other   power_outputs_kw            source  \
# 0                 0          NaN            [250.0]  PlugShare_Scrape
# 1                 0          NaN             [25.0]  PlugShare_Scrape
# 2                 0          NaN            [250.0]  PlugShare_Scrape
# 3                 0          NaN  [50.0, 'unknown']  PlugShare_Scrape
# 4                 1          NaN        ['unknown']  PlugShare_Scrape
#
#    source_date  whether_evcs
# 0   20/08/2022           yes
# 1   20/08/2022           yes
# 2   20/08/2022            no
# 3   20/08/2022           yes
# 4   20/08/2022            no
#
# [5 rows x 25 columns]

# %%
# Define a function to distinguish lonely stations
def select_marker_color(row):
    if row["whether_evcs"] == "yes":
        return "red"
    elif row["whether_evcs"] == "no" and row["total_plugs"] == "['unknown']":
        return "grey"
    return "green"

# %%
# Apply the rules to the dataset
stations["colour"] = stations.apply(select_marker_color, axis = 1)
stations.head()
# Out:
#                                         name  \
# 0                       Geelong Supercharger
# 1            Penguin Parade Visitor's Centre
# 2                    Mornington Supercharger
# 3  Kingston Village Square (DC Fast Charger)
# 4           BIG4 Phillip Island Caravan Park
#
#                                              address   longitude   latitude  \
# 0  470-510 Princes Hwy, Geelong, VIC, Australia, ...  144.382451 -38.065192
# 1   995 Ventnor Road Summerlands VIC 3922, Australia  145.148488 -38.505496
# 2  75 Mornington-Tyabb Rd, Mornington VIC 3931, A...  145.051085 -38.234305
# 3  Kingston Village Square, Grubb Rd, Ocean Grove...  144.540122 -38.246677
# 4  24 Old Bridge Drive, Newhaven VIC 3925, Australia  145.356460 -38.516829
#
#    description  parking  pricing      contact           networks  total_plugs  \
# 0          NaN      NaN      NaN  61280152834   ['Supercharger']            6
# 1          NaN      NaN      NaN          NaN  ['Non-networked']            2
# 2          NaN      NaN      NaN  61280152834   ['Supercharger']            6
# 3          NaN      NaN      NaN   1300518038      ['Chargefox']            4
# 4          NaN      NaN      NaN   0359567227  ['Non-networked']            2
#
#    ...  Plugs_Three_Phase  Plugs_Commando  Plugs_Type2  Plugs_Wall_AU_NZ  \
# 0  ...                  0             NaN            0                 0
# 1  ...                  0             NaN            0                 0
# 2  ...                  0             NaN            0                 0
# 3  ...                  0             NaN            2                 0
# 4  ...                  0             NaN            0                 1
#
#    Plugs_Other   power_outputs_kw            source  source_date  \
# 0          NaN            [250.0]  PlugShare_Scrape   20/08/2022
# 1          NaN             [25.0]  PlugShare_Scrape   20/08/2022
# 2          NaN            [250.0]  PlugShare_Scrape   20/08/2022
# 3          NaN  [50.0, 'unknown']  PlugShare_Scrape   20/08/2022
# 4          NaN        ['unknown']  PlugShare_Scrape   20/08/2022
#
#    whether_evcs  colour
# 0           yes     red
# 1           yes     red
# 2            no   green
# 3           yes     red
# 4            no   green
#
# [5 rows x 26 columns]

# %%
# Create an interactive map with distinguished colours and labels of station information
my_map = folium.Map(location = [-37.884254, 144.736465], width = 1000, height = 600)

for _, station in stations.iterrows():
    folium.Marker(location = [station["latitude"], station["longitude"]],
                  # Click each EVCS for popups: extra info can be added by demand
                 popup = [station["name"], station["total_plugs"]], 
                 tooltip = station["name"],
                 icon = folium.Icon(color = station["colour"])).add_to(my_map)

my_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_70a98ff50bb4a32a76bd2da495ac244b {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_70a98ff50bb4a32a76bd2da495ac244b&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_70a98ff50bb4a32a76bd2da495ac244b = L.map(
#                 &quot;map_70a98ff50bb4a32a76bd2da495ac244b&quot;,
#                 {
#                     center: [-37.884254, 144.736465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8491adee5328e38eb68ba48f3a9b048b = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_70a98ff50bb4a32a76bd2da495ac244b);
#
#
#             var marker_d6abdf50a43e5f342231d1280a20fc70 = L.marker(
#                 [-38.065191999999996, 144.382451],
#                 {}
#             ).addTo(map_70a98ff50bb4a32a76bd2da495ac244b);
#
#
#             var icon_b71898f073e12d7858a627fffd47319c = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_d6abdf50a43e5f342231d1280a20fc70.setIcon(icon_b71898f073e12d7858a627fffd47319c);
#
#
#         var popup_75a6424f306093356cc2e1aadef0578f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_c1ac7fcb5b7f5043c86b4b36c9be7a91 = $(`&lt;div id=&quot;html_c1ac7fcb5b7f5043c86b4b36c9be7a91&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Geelong Supercharger&#x27;, 6]&lt;/div&gt;`)[0];
#             popup_75a6424f306093356cc2e1aadef0578f.setContent(html_c1ac7fcb5b7f5043c86b4b36c9be7a91);
#
#
#         marker_d6abdf50a43e5f342231d1280a20fc70.bindPopup(popup_75a6424f306093356cc2e1aadef0578f)
#         ;
#
#
#
#
#             marker_d6abdf50a43e5f342231d1280a20fc70.bindTooltip(
#                 `&lt;div&gt;
#                      Geelong Supercharger
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_7d08e646ddc62d9da0b24bc46ae23023 = L.marker(
#                 [-38.505496, 145.148488],
#                 {}
#             ).addTo(map_70a98ff50bb4a32a76bd2da495ac244b);
#
#
#             var icon_44e2c7605e2f69689530699e0310b48d = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_7d08e646ddc62d9da0b24bc46ae23023.setIcon(icon_44e2c7605e2f69689530699e0310b48d);
#
#
#         var popup_b6857c74ba181c26a5bc52a9c4d2506f = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_df6c62fcf2afc83d60f8370e46605da6 = $(`&lt;div id=&quot;html_df6c62fcf2afc83d60f8370e46605da6&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&quot;Penguin Parade Visitor&#x27;s Centre&quot;, 2]&lt;/div&gt;`)[0];
#             popup_b6857c74ba181c26a5bc52a9c4d2506f.setContent(html_df6c62fcf2afc83d60f8370e46605da6);
#
#
#         marker_7d08e646ddc62d9da0b24bc46ae23023.bindPopup(popup_b6857c74ba181c26a5bc52a9c4d2506f)
#         ;
#
#
#
#
#             marker_7d08e646ddc62d9da0b24bc46ae23023.bindTooltip(
#                 `&lt;div&gt;
#                      Penguin Parade Visitor&#x27;s Centre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_40f356508561a9add9c29946d2e3e8cf = L.marker(
#                 [-38.234305, 145.051085],
#                 {}
#             ).addTo(map_70a98ff50bb4a32a76bd2da495ac244b);
#
#
#             var icon_07b51b8cc0b1d235503f19c96990bc13 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;info-sign&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_40f356508561a9add9c29946d2e3e8cf.setIcon(icon_07b51b8cc0b1d235503f19c96990bc13);
#
#
#         var popup_d8c4c39b24cf26c08c03b57b9c005c0a = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_e5635f1a16b6ebca3c8da6f06f615681 = $(`&lt;div id=&quot;html_e5635f1a16b6ebca3c8da6f06f615681&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Mornington Supercharger&#x27;, 6]&lt;/div&gt;`)[0];
#             popup_d8c4c39b24cf26c08c03b57b9c005c0a.setContent(html_e5635f1a16b6ebca3c8da6f06f615681);
#
#
#         marker_40f356508561a9add9c29946d2e3e8cf.bindPopup(popup_d8c4c39b24cf26c08c03b57b9c005c0a)
#         ;

# %% [markdown]
# ### New EVCS Location Recommendation

# %%
# Load off-street parking lot dataset
parking = pd.read_csv("Off-street_car_parking_2020.csv")
parking.head()
# Out:
#    Census year  Block ID  Property ID  Base property ID  \
# 0         2020         1       108843            108843
# 1         2020         1       611393            611393
# 2         2020         1       611394            611394
# 3         2020         1       611394            611394
# 4         2020         6       578328            573333
#
#                                     Building address  CLUE small area  \
# 0               2-92 Rebecca Walk MELBOURNE VIC 3000  Melbourne (CBD)
# 1         507-541 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 2         545-557 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 3         545-557 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 4  Carpark Federation Square 2 Swanston Street ME...  Melbourne (CBD)
#
#   Parking type  Parking spaces  x coordinate  y coordinate
# 0   Commercial              50     144.95687     -37.82121
# 1      Private              29     144.95721     -37.82087
# 2   Commercial             146     144.95651     -37.82098
# 3  Residential             137     144.95651     -37.82098
# 4   Commercial             450     144.96982     -37.81779

# %%
parking.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7184 entries, 0 to 7183
# Data columns (total 10 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Census year       7184 non-null   int64
#  1   Block ID          7184 non-null   int64
#  2   Property ID       7184 non-null   int64
#  3   Base property ID  7184 non-null   int64
#  4   Building address  7184 non-null   object
#  5   CLUE small area   7184 non-null   object
#  6   Parking type      7184 non-null   object
#  7   Parking spaces    7184 non-null   int64
#  8   x coordinate      7183 non-null   float64
#  9   y coordinate      7183 non-null   float64
# dtypes: float64(2), int64(5), object(3)
# memory usage: 561.4+ KB

# %%
# Filter based on various types of parking type
# parking = parking.loc[(parking["Parking type"] == "Commercial") | (parking["Parking type"] == "Residential")]
# parking.head()
# Out:
#    Census year  Block ID  Property ID  Base property ID  \
# 0         2020         1       108843            108843
# 2         2020         1       611394            611394
# 3         2020         1       611394            611394
# 4         2020         6       578328            573333
# 5         2020        11       103957            103957
#
#                                     Building address  CLUE small area  \
# 0               2-92 Rebecca Walk MELBOURNE VIC 3000  Melbourne (CBD)
# 2         545-557 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 3         545-557 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 4  Carpark Federation Square 2 Swanston Street ME...  Melbourne (CBD)
# 5           517-537 Flinders Lane MELBOURNE VIC 3000  Melbourne (CBD)
#
#   Parking type  Parking spaces  x coordinate  y coordinate
# 0   Commercial              50     144.95687     -37.82121
# 2   Commercial             146     144.95651     -37.82098
# 3  Residential             137     144.95651     -37.82098
# 4   Commercial             450     144.96982     -37.81779
# 5   Commercial             117     144.95666     -37.81987

# %%
# Filter based on the parking spaces - we assume parking lots with more than 100 spaces would have potentials in new EVCSs
parking = parking.loc[parking["Parking spaces"] > 100]
parking.shape
# Out:
# (442, 10)

# %%
# Create new list for storing parking lot coordinates
parking_coordinates = []

for _, park in parking.iterrows():
    p = [[park["y coordinate"], park["x coordinate"]]]
    parking_coordinates += p

# %%
parking["future_ev_site"] = ""

for i in range(len(parking_coordinates)):
    location2 = parking_coordinates[i]
    evcs_counts = 0
    
    for j in range(len(coordinates)):
        
        if i == j:
            pass
        elif distance(coordinates[j], location2) < 2:
            evcs_counts += 1
        else:
            evcs_counts += 0
            
    if evcs_counts > 0:
        parking["future_ev_site"].iloc[i] = "n"
    else:
        parking["future_ev_site"].iloc[i] = "y"

parking.head()
# Out:
#    Census year  Block ID  Property ID  Base property ID  \
# 2         2020         1       611394            611394
# 3         2020         1       611394            611394
# 4         2020         6       578328            573333
# 5         2020        11       103957            103957
# 6         2020        11       103987            103987
#
#                                     Building address  CLUE small area  \
# 2         545-557 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 3         545-557 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
# 4  Carpark Federation Square 2 Swanston Street ME...  Melbourne (CBD)
# 5           517-537 Flinders Lane MELBOURNE VIC 3000  Melbourne (CBD)
# 6         550-554 Flinders Street MELBOURNE VIC 3000  Melbourne (CBD)
#
#   Parking type  Parking spaces  x coordinate  y coordinate future_ev_site
# 2   Commercial             146     144.95651     -37.82098              n
# 3  Residential             137     144.95651     -37.82098              n
# 4   Commercial             450     144.96982     -37.81779              n
# 5   Commercial             117     144.95666     -37.81987              n
# 6  Residential             152     144.95597     -37.82039              n

# %%
parking["future_ev_site"].unique()
# Out:
# array(['n', 'y'], dtype=object)

# %%
# Mapping the parking lot dataset
parking_map = folium.Map(location = [-37.82098, 144.95651], width = 1000, height = 600)

for _, park in parking.iterrows():
    folium.Marker(location = [park["y coordinate"], park["x coordinate"]],
                 popup = park["Property ID"]).add_to(parking_map)

parking_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_a3099ee7920c1cbf07b128f7c05feee6 {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_a3099ee7920c1cbf07b128f7c05feee6&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_a3099ee7920c1cbf07b128f7c05feee6 = L.map(
#                 &quot;map_a3099ee7920c1cbf07b128f7c05feee6&quot;,
#                 {
#                     center: [-37.82098, 144.95651],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_6afd3a4d494843a89e1138427d4b7751 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#             var marker_ef69835563aa05b3519f04ed44a9000f = L.marker(
#                 [-37.82098, 144.95651],
#                 {}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#         var popup_41eb9463cf7d142fae2a772adc2d3fe1 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_8b36bf779e41edfda55d609dc8b06ddb = $(`&lt;div id=&quot;html_8b36bf779e41edfda55d609dc8b06ddb&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;611394&lt;/div&gt;`)[0];
#             popup_41eb9463cf7d142fae2a772adc2d3fe1.setContent(html_8b36bf779e41edfda55d609dc8b06ddb);
#
#
#         marker_ef69835563aa05b3519f04ed44a9000f.bindPopup(popup_41eb9463cf7d142fae2a772adc2d3fe1)
#         ;
#
#
#
#
#             var marker_5c91fa3b3d94bfe60940d4da46d09eb2 = L.marker(
#                 [-37.82098, 144.95651],
#                 {}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#         var popup_bf0903863a92252854745eb109999ea2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_79bfe442434467e44e86b29482dddc60 = $(`&lt;div id=&quot;html_79bfe442434467e44e86b29482dddc60&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;611394&lt;/div&gt;`)[0];
#             popup_bf0903863a92252854745eb109999ea2.setContent(html_79bfe442434467e44e86b29482dddc60);
#
#
#         marker_5c91fa3b3d94bfe60940d4da46d09eb2.bindPopup(popup_bf0903863a92252854745eb109999ea2)
#         ;
#
#
#
#
#             var marker_29371c2f136d89948a865b791ad1bb6b = L.marker(
#                 [-37.81779, 144.96982],
#                 {}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#         var popup_fab6ffd0ca4a5a4d8fc7f187f0b66952 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_378cbd78af0dead512feddb4e52edfec = $(`&lt;div id=&quot;html_378cbd78af0dead512feddb4e52edfec&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;578328&lt;/div&gt;`)[0];
#             popup_fab6ffd0ca4a5a4d8fc7f187f0b66952.setContent(html_378cbd78af0dead512feddb4e52edfec);
#
#
#         marker_29371c2f136d89948a865b791ad1bb6b.bindPopup(popup_fab6ffd0ca4a5a4d8fc7f187f0b66952)
#         ;
#
#
#
#
#             var marker_21f050f788ad4879a4c97c4d8f9f987b = L.marker(
#                 [-37.81987, 144.95666],
#                 {}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#         var popup_98cf7c5188737de7f4487a137bdd4b81 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_a413051960386bd56fc4aab95e191b85 = $(`&lt;div id=&quot;html_a413051960386bd56fc4aab95e191b85&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103957&lt;/div&gt;`)[0];
#             popup_98cf7c5188737de7f4487a137bdd4b81.setContent(html_a413051960386bd56fc4aab95e191b85);
#
#
#         marker_21f050f788ad4879a4c97c4d8f9f987b.bindPopup(popup_98cf7c5188737de7f4487a137bdd4b81)
#         ;
#
#
#
#
#             var marker_1812b59333b614bb0a80ec25b094cae5 = L.marker(
#                 [-37.82039, 144.95597],
#                 {}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#         var popup_ef1181472a6f64cffe930fd0d96d2b7d = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_51334cab6874028f4c3163f52ef84a56 = $(`&lt;div id=&quot;html_51334cab6874028f4c3163f52ef84a56&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;103987&lt;/div&gt;`)[0];
#             popup_ef1181472a6f64cffe930fd0d96d2b7d.setContent(html_51334cab6874028f4c3163f52ef84a56);
#
#
#         marker_1812b59333b614bb0a80ec25b094cae5.bindPopup(popup_ef1181472a6f64cffe930fd0d96d2b7d)
#         ;
#
#
#
#
#             var marker_a1f70dbbe571991f825ea8b4884cca38 = L.marker(
#                 [-37.81973, 144.95827],
#                 {}
#             ).addTo(map_a3099ee7920c1cbf07b128f7c05feee6);
#
#
#         var popup_a3fadb3a464a44c98c68309c735bdf85 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_6d40d809dd084732f2b6110936ab289b = $(`&lt;div id=&quot;html_6d40d809dd084732f2b6110936ab289b&quot; style=&quot;width: 100.0%; hei

# %%
# Create a new dataset with sorted information
newdata = stations[["name", "address", "longitude", "latitude", "whether_evcs", "colour"]]
newdata.head()
# Out:
#                                         name  \
# 0                       Geelong Supercharger
# 1            Penguin Parade Visitor's Centre
# 2                    Mornington Supercharger
# 3  Kingston Village Square (DC Fast Charger)
# 4           BIG4 Phillip Island Caravan Park
#
#                                              address   longitude   latitude  \
# 0  470-510 Princes Hwy, Geelong, VIC, Australia, ...  144.382451 -38.065192
# 1   995 Ventnor Road Summerlands VIC 3922, Australia  145.148488 -38.505496
# 2  75 Mornington-Tyabb Rd, Mornington VIC 3931, A...  145.051085 -38.234305
# 3  Kingston Village Square, Grubb Rd, Ocean Grove...  144.540122 -38.246677
# 4  24 Old Bridge Drive, Newhaven VIC 3925, Australia  145.356460 -38.516829
#
#   whether_evcs colour
# 0          yes    red
# 1          yes    red
# 2           no  green
# 3          yes    red
# 4           no  green

# %%
# New recommended EVCSs are marked as blue
new_evcs = parking.loc[parking["future_ev_site"] == "y"]
new_evcs = new_evcs[["Block ID", "Building address", "x coordinate", "y coordinate", "future_ev_site"]]
new_evcs["colour"] = "blue"
new_evcs.head()
# Out:
#       Block ID                                   Building address  \
# 4367       571  Melbourne Showgrounds 276-318 Epsom Road FLEMI...
# 6706       928             57-63 Galada Avenue PARKVILLE VIC 3052
# 6707       928             51-55 Galada Avenue PARKVILLE VIC 3052
#
#       x coordinate  y coordinate future_ev_site colour
# 4367     144.91158     -37.78218              y   blue
# 6706     144.93949     -37.78010              y   blue
# 6707     144.93959     -37.78036              y   blue

# %%
# Rename the new dataset
new_evcs.rename(columns = {"Block ID": "name", "Building address": "address", "x coordinate": "longitude", 
                   "y coordinate": "latitude", "future_ev_site": "whether_evcs", "colour": "colour"},
        inplace = True)
new_evcs
# Out:
#       name                                            address  longitude  \
# 4367   571  Melbourne Showgrounds 276-318 Epsom Road FLEMI...  144.91158
# 6706   928             57-63 Galada Avenue PARKVILLE VIC 3052  144.93949
# 6707   928             51-55 Galada Avenue PARKVILLE VIC 3052  144.93959
#
#       latitude whether_evcs colour
# 4367 -37.78218            y   blue
# 6706 -37.78010            y   blue
# 6707 -37.78036            y   blue

# %%
# Integarated dataset
frames = [newdata, new_evcs]
result = pd.concat(frames)
result
# Out:
#                                            name  \
# 0                          Geelong Supercharger
# 1               Penguin Parade Visitor's Centre
# 2                       Mornington Supercharger
# 3     Kingston Village Square (DC Fast Charger)
# 4              BIG4 Phillip Island Caravan Park
# ...                                         ...
# 248                          Lorbek Luxury Cars
# 249                          Lorbek Luxury Cars
# 4367                                        571
# 6706                                        928
# 6707                                        928
#
#                                                 address   longitude  \
# 0     470-510 Princes Hwy, Geelong, VIC, Australia, ...  144.382451
# 1      995 Ventnor Road Summerlands VIC 3922, Australia  145.148488
# 2     75 Mornington-Tyabb Rd, Mornington VIC 3931, A...  145.051085
# 3     Kingston Village Square, Grubb Rd, Ocean Grove...  144.540122
# 4     24 Old Bridge Drive, Newhaven VIC 3925, Australia  145.356460
# ...                                                 ...         ...
# 248   327 Plummer St, Port Melbourne VIC 3207, Austr...  144.919764
# 249   30 Prohasky St, Port Melbourne VIC 3207, Austr...  144.919335
# 4367  Melbourne Showgrounds 276-318 Epsom Road FLEMI...  144.911580
# 6706             57-63 Galada Avenue PARKVILLE VIC 3052  144.939490
# 6707             51-55 Galada Avenue PARKVILLE VIC 3052  144.939590
#
#        latitude whether_evcs colour
# 0    -38.065192          yes    red
# 1    -38.505496          yes    red
# 2    -38.234305           no  green
# 3    -38.246677          yes    red
# 4    -38.516829           no  green
# ...         ...          ...    ...
# 248  -37.833209           no  green
# 249  -37.832093           no  green
# 4367 -37.782180            y   blue
# 6706 -37.780100            y   blue
# 6707 -37.780360            y   blue
#
# [253 rows x 6 columns]

# %%
# Re-define the colour function
def select_marker_icon(row):
    if row["colour"] == "red":
        return "star"
    elif row["colour"] == "blue":
        return "heart"
    return "flash"

# %%
# Icon function added for map generation
result["icon"] = result.apply(select_marker_icon, axis = 1)
result.head()
# Out:
#                                         name  \
# 0                       Geelong Supercharger
# 1            Penguin Parade Visitor's Centre
# 2                    Mornington Supercharger
# 3  Kingston Village Square (DC Fast Charger)
# 4           BIG4 Phillip Island Caravan Park
#
#                                              address   longitude   latitude  \
# 0  470-510 Princes Hwy, Geelong, VIC, Australia, ...  144.382451 -38.065192
# 1   995 Ventnor Road Summerlands VIC 3922, Australia  145.148488 -38.505496
# 2  75 Mornington-Tyabb Rd, Mornington VIC 3931, A...  145.051085 -38.234305
# 3  Kingston Village Square, Grubb Rd, Ocean Grove...  144.540122 -38.246677
# 4  24 Old Bridge Drive, Newhaven VIC 3925, Australia  145.356460 -38.516829
#
#   whether_evcs colour   icon
# 0          yes    red   star
# 1          yes    red   star
# 2           no  green  flash
# 3          yes    red   star
# 4           no  green  flash

# %%
# New map with future EVCS recommendations
new_map = folium.Map(location = [-37.884254, 144.736465], width = 1000, height = 600)

for _, r in result.iterrows():
    folium.Marker(location = [r["latitude"], r["longitude"]],
                 popup = [r["name"], r["address"]],
                 tooltip = r["name"],
                 icon = folium.Icon(icon = r["icon"], color = r["colour"])).add_to(new_map)

new_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84dc1e2a0fdddb6e010a7865a61eeabd {
#                     position: relative;
#                     width: 1000.0px;
#                     height: 600.0px;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84dc1e2a0fdddb6e010a7865a61eeabd&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_84dc1e2a0fdddb6e010a7865a61eeabd = L.map(
#                 &quot;map_84dc1e2a0fdddb6e010a7865a61eeabd&quot;,
#                 {
#                     center: [-37.884254, 144.736465],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 10,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_4712551c056f346dc790e336c37b654e = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_84dc1e2a0fdddb6e010a7865a61eeabd);
#
#
#             var marker_3ebf0954e5ea604dcbe05468d8350687 = L.marker(
#                 [-38.065191999999996, 144.382451],
#                 {}
#             ).addTo(map_84dc1e2a0fdddb6e010a7865a61eeabd);
#
#
#             var icon_29e3915da2d3eff1924622b7f0f3f232 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_3ebf0954e5ea604dcbe05468d8350687.setIcon(icon_29e3915da2d3eff1924622b7f0f3f232);
#
#
#         var popup_273bab88e7e170462b5c629958bc3eba = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_93341302926df9ebe7e7319d7a269370 = $(`&lt;div id=&quot;html_93341302926df9ebe7e7319d7a269370&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Geelong Supercharger&#x27;, &#x27;470-510 Princes Hwy, Geelong, VIC, Australia, 3214&#x27;]&lt;/div&gt;`)[0];
#             popup_273bab88e7e170462b5c629958bc3eba.setContent(html_93341302926df9ebe7e7319d7a269370);
#
#
#         marker_3ebf0954e5ea604dcbe05468d8350687.bindPopup(popup_273bab88e7e170462b5c629958bc3eba)
#         ;
#
#
#
#
#             marker_3ebf0954e5ea604dcbe05468d8350687.bindTooltip(
#                 `&lt;div&gt;
#                      Geelong Supercharger
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_9cfcd412fdf1c33161b9302e64fdebf7 = L.marker(
#                 [-38.505496, 145.148488],
#                 {}
#             ).addTo(map_84dc1e2a0fdddb6e010a7865a61eeabd);
#
#
#             var icon_9b0be585a2d0f08d0f84edd56054741f = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;star&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;red&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_9cfcd412fdf1c33161b9302e64fdebf7.setIcon(icon_9b0be585a2d0f08d0f84edd56054741f);
#
#
#         var popup_66a1770e84c6e2316077217d3053b4f2 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_1edcf7459643d30c272146809c5d6bf8 = $(`&lt;div id=&quot;html_1edcf7459643d30c272146809c5d6bf8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&quot;Penguin Parade Visitor&#x27;s Centre&quot;, &#x27;995 Ventnor Road Summerlands VIC 3922, Australia&#x27;]&lt;/div&gt;`)[0];
#             popup_66a1770e84c6e2316077217d3053b4f2.setContent(html_1edcf7459643d30c272146809c5d6bf8);
#
#
#         marker_9cfcd412fdf1c33161b9302e64fdebf7.bindPopup(popup_66a1770e84c6e2316077217d3053b4f2)
#         ;
#
#
#
#
#             marker_9cfcd412fdf1c33161b9302e64fdebf7.bindTooltip(
#                 `&lt;div&gt;
#                      Penguin Parade Visitor&#x27;s Centre
#                  &lt;/div&gt;`,
#                 {&quot;sticky&quot;: true}
#             );
#
#
#             var marker_31a2b7c6f725f3d6ed87f01df2e26366 = L.marker(
#                 [-38.234305, 145.051085],
#                 {}
#             ).addTo(map_84dc1e2a0fdddb6e010a7865a61eeabd);
#
#
#             var icon_12ab88cb606ade74cba8a7a22cb24ee5 = L.AwesomeMarkers.icon(
#                 {&quot;extraClasses&quot;: &quot;fa-rotate-0&quot;, &quot;icon&quot;: &quot;flash&quot;, &quot;iconColor&quot;: &quot;white&quot;, &quot;markerColor&quot;: &quot;green&quot;, &quot;prefix&quot;: &quot;glyphicon&quot;}
#             );
#             marker_31a2b7c6f725f3d6ed87f01df2e26366.setIcon(icon_12ab88cb606ade74cba8a7a22cb24ee5);
#
#
#         var popup_a5a3b9b812d36283144045eabc7ae220 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#             var html_64a88ef1d1b3e205efe02c247e1dc906 = $(`&lt;div id=&quot;html_64a88ef1d1b3e205efe02c247e1dc906&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;[&#x27;Mornington Supercharger&#x27;, &#x27;75 Mornington-Tyabb Rd, Mornington VIC 3931, Australia&#x27;]&lt;/div&gt;`)[0];
#             popup_a5a3b9b812d36283144045eabc7ae220.setContent(html_64a88ef1d

# %% [markdown]
# The END
