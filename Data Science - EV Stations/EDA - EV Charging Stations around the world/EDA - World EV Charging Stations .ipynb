# %% [markdown]
# # EDA - World EV Charging Stations

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Importing Libraries & Setting Up Data

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame
import matplotlib.pyplot as plt
from matplotlib import rcParams
import warnings
warnings.filterwarnings("ignore")

# %%
address = 'C:/Users/west5/OneDrive - Deakin University/Desktop/Git_Repositories_Working/EVCFLO/Data Science - EV Stations/Data/IEA-EV-data.csv'

ev = pd.read_csv(address)

ev.columns = ['region', 'category', 'parameter', 'mode', 'powertrain', 'year', 'unit', 'value']
ev.head(50)
# Out:
#        region    category           parameter  mode               powertrain  \
# 0   Australia  Historical            EV sales  Cars                      BEV
# 1   Australia  Historical            EV stock  Cars                      BEV
# 2   Australia  Historical      EV stock share  Cars                       EV
# 3   Australia  Historical      EV sales share  Cars                       EV
# 4   Australia  Historical      EV sales share  Cars                       EV
# 5   Australia  Historical      EV stock share  Cars                       EV
# 6   Australia  Historical            EV stock  Cars                      BEV
# 7   Australia  Historical            EV sales  Cars                     PHEV
# 8   Australia  Historical            EV sales  Cars                      BEV
# 9   Australia  Historical            EV stock  Cars                     PHEV
# 10  Australia  Historical            EV stock  Cars                     PHEV
# 11  Australia  Historical            EV sales  Cars                      BEV
# 12  Australia  Historical            EV sales  Cars                     PHEV
# 13  Australia  Historical            EV stock  Cars                      BEV
# 14  Australia  Historical      EV stock share  Cars                       EV
# 15  Australia  Historical      EV sales share  Cars                       EV
# 16  Australia  Historical      EV sales share  Cars                       EV
# 17  Australia  Historical      EV stock share  Cars                       EV
# 18  Australia  Historical            EV stock  Cars                      BEV
# 19  Australia  Historical            EV sales  Cars                     PHEV
# 20  Australia  Historical            EV sales  Cars                      BEV
# 21  Australia  Historical            EV stock  Cars                     PHEV
# 22  Australia  Historical            EV stock  Cars                     PHEV
# 23  Australia  Historical            EV sales  Cars                      BEV
# 24  Australia  Historical            EV sales  Cars                     PHEV
# 25  Australia  Historical            EV stock  Cars                      BEV
# 26  Australia  Historical      EV stock share  Cars                       EV
# 27  Australia  Historical      EV sales share  Cars                       EV
# 28  Australia  Historical      EV sales share  Cars                       EV
# 29  Australia  Historical      EV stock share  Cars                       EV
# 30  Australia  Historical            EV stock  Cars                      BEV
# 31  Australia  Historical            EV sales  Cars                     PHEV
# 32  Australia  Historical            EV sales  Cars                      BEV
# 33  Australia  Historical            EV stock  Cars                     PHEV
# 34  Australia  Historical            EV stock  Cars                     PHEV
# 35  Australia  Historical            EV sales  Cars                      BEV
# 36  Australia  Historical            EV sales  Cars                     PHEV
# 37  Australia  Historical            EV stock  Cars                      BEV
# 38  Australia  Historical  EV charging points    EV  Publicly available fast
# 39  Australia  Historical  EV charging points    EV  Publicly available slow
# 40  Australia  Historical      EV sales share  Cars                       EV
# 41  Australia  Historical      EV stock share  Cars                       EV
# 42  Australia  Historical      EV stock share  Cars                       EV
# 43  Australia  Historical      EV sales share  Cars                       EV
# 44  Australia  Historical  EV charging points    EV  Publicly available fast
# 45  Australia  Historical  EV charging points    EV  Publicly available slow
# 46  Australia  Historical            EV stock  Cars                      BEV
# 47  Australia  Historical            EV sales  Cars                     PHEV
# 48  Australia  Historical            EV sales  Cars                      BEV
# 49  Australia  Historical            EV stock  Cars                     PHEV
#
#     year             unit       value
# 0   2011            sales    49.00000
# 1   2011            stock    49.00000
# 2   2011          percent     0.00046
# 3   2011          percent     0.00650
# 4   2012          percent     0.03000
# 5   2012          percent     0.00280
# 6   2012            stock   220.00000
# 7   2012            sales    80.00000
# 8   2012            sales   170.00000
# 9   2012            stock    80.00000
# 10  2013            stock   180.00000
# 11  2013            sales   190.00000
# 12  2013            sales   100.00000
# 13  2013            stock   410.00000
# 14  2013          percent     0.00540
# 15  2013          percent     0.03400
# 16  2014          percent     0.16000
# 17  2014          percent     0.01700
# 18  2014            stock   780.00000
# 19  2014            sales   950.00000
# 20  2014            sales   370.00000
# 21  2014            stock  1100.00000
# 22  2015            stock  2100.00000
# 23  2015            sales   760.00000
# 24  2015            sales  1000.00000
# 25  2015            stock  1500.00000
# 26  2015          percent     0.03200
# 27  2015          percent     0.20000
# 28  2016          percent     0.15000
# 29  2016          percent     0.04300
# 30  2016            stock  2200.00000
# 31  2016            sales   700.00000
# 32  2016            sales   670.00000
# 33  2016            stock  2800.00000
# 34  2017            stock  3900.00000
# 35  2017            sales  1200.00000
# 36  2017            sales  1100.00000
# 37  2017            stock  3400.00000
# 38  2017  charging points    40.00000
# 39  2017  charging points   440.00000
# 40  2017          percent     0.26000
# 41  2017          percent     0.06100
# 42  2018          percent     0.08900
# 43  2018          percent     0.42000
# 44  2018  charging points    61.00000
# 45  2018  charging points   670.00000
# 46  2018            stock  5200.00000
# 47  2018            sales  1800.00000
# 48  2018            sales  1800.00000
# 49  2018            stock  5700.00000

# %% [markdown]
# ### Treating Duplicates & Missing Values

# %%
# Count Missing Values
print('Missing Values by Attribute:')
print(ev.isnull().sum())

# Filter Out Missing Values
ev_no_nan = ev.dropna(axis=0)
ev_no_nan2 = ev.dropna(axis=1)
print('\nShape before filtering missing values: ' + str(ev.shape))
print('Shape after filtering missing values by row: ' + str(ev_no_nan.shape))
print('Shape after filtering missing values by column: ' + str(ev_no_nan2.shape))
# Out:
# Missing Values by Attribute:
# region        0
# category      0
# parameter     0
# mode          0
# powertrain    0
# year          0
# unit          0
# value         0
# dtype: int64
#
# Shape before filtering missing values: (7434, 8)
# Shape after filtering missing values by row: (7434, 8)
# Shape after filtering missing values by column: (7434, 8)

# %% [markdown]
# There are no missing values in the dataframe by either row or column. Therefore the shape before and after filtering is the same. No missing data is detected.

# %%
# Counting and dropping duplicated Data Values
counted = ev.duplicated().sum()
print('Number of duplicated data values: ' + str(counted))
print('Shape before dropping duplicates: ' + str(ev.shape))
ev2 = ev.drop_duplicates()
print('Shape after dropping duplicates: ' + str(ev2.shape))
# Out:
# Number of duplicated data values: 0
# Shape before dropping duplicates: (7434, 8)
# Shape after dropping duplicates: (7434, 8)

# %% [markdown]
# There are no duplicated rows detected in the data frame. As such the shape is the before and after dropping duplicates.

# %% [markdown]
# ### Sorting, Selecting & Grouping Data

# %%
ev.head()
# Out:
#       region    category       parameter  mode powertrain  year     unit  \
# 0  Australia  Historical        EV sales  Cars        BEV  2011    sales
# 1  Australia  Historical        EV stock  Cars        BEV  2011    stock
# 2  Australia  Historical  EV stock share  Cars         EV  2011  percent
# 3  Australia  Historical  EV sales share  Cars         EV  2011  percent
# 4  Australia  Historical  EV sales share  Cars         EV  2012  percent
#
#       value
# 0  49.00000
# 1  49.00000
# 2   0.00046
# 3   0.00650
# 4   0.03000

# %%
# Displaying Value Counts Per Attribute
with pd.option_context('display.max_rows', None,):
    print('5 largest regions:')
    print(ev['region'].value_counts().nlargest(5))
    print()

with pd.option_context('display.max_rows', None,):
    print('Value Counts by Category:')
    print(ev['category'].value_counts())
    print()    

with pd.option_context('display.max_rows', None,):
    print('Value Counts by Parameter:')
    print(ev['parameter'].value_counts())
    print()
with pd.option_context('display.max_rows', None,):
    print('Value Counts by mode:')
    print(ev['mode'].value_counts())
    print()
with pd.option_context('display.max_rows', None,):
    print('Value Counts by PowerTrain:')
    print(ev['powertrain'].value_counts())
    print()
with pd.option_context('display.max_rows', None,):
    print('Value Counts by Year:')
    print(ev['year'].value_counts())
    print()
with pd.option_context('display.max_rows', None,):
    print('Value Counts by Unit:')
    print(ev['unit'].value_counts())
    print()
# Out:
# 5 largest regions:
# World                763
# China                751
# Europe               584
# Rest of the world    451
# USA                  343
# Name: region, dtype: int64
#
# Value Counts by Category:
# Historical          5686
# Projection-APS       874
# Projection-STEPS     874
# Name: category, dtype: int64
#
# Value Counts by Parameter:
# EV stock                 1723
# EV sales                 1609
# EV stock share           1096
# EV sales share           1059
# EV charging points        623
# Electricity demand        576
# Oil displacement Mbd      374
# Oil displacement Mlge     374
# Name: parameter, dtype: int64
#
# Value Counts by mode:
# Cars         2684
# Vans         1625
# Buses        1436
# Trucks       1058
# EV            623
# SSPACEHHP       8
# Name: mode, dtype: int64
#
# Value Counts by PowerTrain:
# EV                         2903
# BEV                        2373
# PHEV                       1535
# Publicly available slow     313
# Publicly available fast     310
# Name: powertrain, dtype: int64
#
# Value Counts by Year:
# 2020    998
# 2021    993
# 2019    606
# 2018    562
# 2017    538
# 2016    510
# 2025    508
# 2030    508
# 2015    466
# 2014    409
# 2013    389
# 2012    374
# 2011    325
# 2010    248
# Name: year, dtype: int64
#
# Value Counts by Unit:
# percent                              2155
# stock                                1723
# sales                                1609
# charging points                       623
# GWh                                   576
# Milion barrels per day                374
# Milion litres gasoline equivalent     374
# Name: unit, dtype: int64

# %% [markdown]
# From looking at the above information from the value counts, we can accertain the target row attributes and useful information. The largest regions for EV sales are China, USA and Europe. In terms of the parameter EV Stock, sales and charging points are of interest. EV charging points should be focused on. Unit should focus on the charging points, sales and stock. Most recent historical data comes from the end of 2021 since this report was published in May 2022.

# %% [markdown]
# ### Group Data for Insights

# %%
# Sorting & Grouping Data
# ev_sorted = ev.sort_values(by=(5), ascending=[False])
# DF_sorted

# Group Data by Region
ev_region = ev.groupby(['region', 'category'])['category'].count()
print(ev_region)

# Group Data by Region
ev2 = ev.groupby(['region', 'parameter', 'mode'])['category'].count()
print(ev2)

# # Groupby multiple columns and aggregate()
# result = ev_groups.groupby(['Courses','Fee'])['Duration'].aggregate('count')
# print(result)

# %%
# Select data by charging points in 2021
ev2 = ev[(ev['parameter'] == 'EV charging points') & (ev['year'] == 2021)]
print('Shape of new data frame: ' + str(ev2.shape))
ev2.head(50)

print('\nRegions with most EV Charging points in 2021:')
ev2['region'].value_counts().nlargest(5)
# ev2['year'].value_counts()
# Out:
# Shape of new data frame: (86, 8)
#
# Regions with most EV Charging points in 2021:
# China     6
# USA       6
# India     6
# World     6
# Europe    4
# Name: region, dtype: int64

# %%
# Sorting & Grouping Data
ev_sorted = ev.sort_values(by=('region'), ascending=[False])
print(ev_sorted)

# Group Data by Region
ev_region = ev.groupby(['region', 'unit'])['region'].count()
print(ev_region)

# Group Data by Region
ev2 = ev.groupby(['region', 'parameter', 'mode'])['category'].count()
print(ev2)

# # Groupby multiple columns and aggregate()
# result = ev_groups.groupby(['Courses','Fee'])['Duration'].aggregate('count')
# print(result)

# ev_groups.mean()
# Out:
#          region          category              parameter   mode  \
# 7433      World  Projection-STEPS  Oil displacement Mlge   Cars
# 6921      World        Historical               EV sales  Buses
# 6930      World        Historical               EV stock  Buses
# 6929      World        Historical               EV stock  Buses
# 6928      World        Historical               EV sales   Cars
# ...         ...               ...                    ...    ...
# 51    Australia        Historical               EV sales   Cars
# 52    Australia        Historical               EV sales   Cars
# 53    Australia        Historical               EV stock   Cars
# 54    Australia        Historical     EV charging points     EV
# 0     Australia        Historical               EV sales   Cars
#
#                    powertrain  year                               unit  \
# 7433                       EV  2030  Milion litres gasoline equivalent
# 6921                      BEV  2017                              sales
# 6930                     PHEV  2017                              stock
# 6929                      BEV  2017                              stock
# 6928                     PHEV  2017                              sales
# ...                       ...   ...                                ...
# 51                        BEV  2019                              sales
# 52                       PHEV  2019                              sales
# 53                        BEV  2019                              stock
# 54    Publicly available fast  2019                    charging points
# 0                         BEV  2011                              sales
#
#          value
# 7433  140000.0
# 6921  120000.0
# 6930   63000.0
# 6929  280000.0
# 6928  420000.0
# ...        ...
# 51      6300.0
# 52      2900.0
# 53     12000.0
# 54       250.0
# 0         49.0
#
# [7434 rows x 8 columns]
# region     unit
# Australia  charging points                       10
#            percent                               22
#            sales                                 21
#            stock                                 21
# Belgium    charging points                       18
#                                                ...
# World      Milion litres gasoline equivalent     80
#            charging points                       40
#            percent                              136
#            sales                                151
#            stock                                152
# Name: region, Length: 148, dtype: int64
# region     parameter              mode
# Australia  EV charging points     EV        10
#            EV sales               Cars      21
#            EV sales share         Cars      11
#            EV stock               Cars      21
#            EV stock share         Cars      11
#                                             ..
# World      Oil displacement Mbd   Vans      20
#            Oil displacement Mlge  Buses     20
#                                   Cars      20
#                                   Trucks    20
#                                   Vans      20
# Name: category, Length: 546, dtype: int64
