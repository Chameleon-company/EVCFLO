# %% [markdown]
# # Import Libraries

# %%
# Import relevant models
from sklearn.linear_model import SGDRegressor # this implements Elastic net regression model
from sklearn.model_selection import train_test_split # creates a training and testing split
import pandas as pd
import numpy as np
import warnings
warnings.filterwarnings("ignore")
import matplotlib.pyplot as plt
# %matplotlib inline


# Import SKLearn Score Metrics
from sklearn.metrics import classification_report
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics.cluster import fowlkes_mallows_score
from sklearn.metrics import f1_score

# Upload dataframe and inspect. 
df = pd.read_csv('Electric and Alternative Fuel Charging Stations.csv')
rows, cols = data.shape
print('The data shape is {} rows and {} columns'.format(rows, cols))
print('\nHead of the data:')
df.head()
# Out:
# The data shape is 70406 rows and 65 columns
#
# Head of the data:
#   Fuel Type Code                                  Station Name  \
# 0            CNG          Spire - Montgomery Operations Center
# 1            CNG                           PS Energy - Atlanta
# 2            CNG  Metropolitan Atlanta Rapid Transit Authority
# 3            CNG                         United Parcel Service
# 4            CNG                    Arkansas Oklahoma Gas Corp
#
#          Street Address                            Intersection Directions  \
# 0      2951 Chestnut St                                                NaN
# 1      340 Whitehall St  From I-7585 N, exit 91 to Central Ave, left on...
# 2   2424 Piedmont Rd NE                                                NaN
# 3  270 Marvin Miller Dr                                                NaN
# 4     2100 S Waldron Rd                                                NaN
#
#          City State    ZIP  Plus4 Station Phone Status Code  ...  \
# 0  Montgomery    AL  36107    NaN           NaN           E  ...
# 1     Atlanta    GA  30303    NaN  770-350-3000           E  ...
# 2     Atlanta    GA  30324    NaN           NaN           E  ...
# 3     Atlanta    GA  30336    NaN           NaN           E  ...
# 4  Fort Smith    AR  72903    NaN  479-783-3188           E  ...
#
#   EV Pricing (French) LPG Nozzle Types Hydrogen Pressures Hydrogen Standards  \
# 0                 NaN              NaN                NaN                NaN
# 1                 NaN              NaN                NaN                NaN
# 2                 NaN              NaN                NaN                NaN
# 3                 NaN              NaN                NaN                NaN
# 4                 NaN              NaN                NaN                NaN
#
#   CNG Fill Type Code CNG PSI CNG Vehicle Class  LNG Vehicle Class  \
# 0                  B    3600                MD                NaN
# 1                  Q    3600                MD                NaN
# 2                  Q    3000                LD                NaN
# 3                  B    3600                HD                NaN
# 4                  Q    3600                MD                NaN
#
#    EV On-Site Renewable Source  Restricted Access
# 0                          NaN                NaN
# 1                          NaN              False
# 2                          NaN                NaN
# 3                          NaN                NaN
# 4                          NaN              False
#
# [5 rows x 65 columns]

# %% [markdown]
# # Conducting Exploratory Data Analysis

# %%
# INSPECTING THE DATAFRAME
# Display the shape and number of null values.  
print('Shape of the NM EV Data: ' + str(df.shape) + '\n'*2)
print('DATAFRAME INFORMATION')
df.info()
print('\n'*3)

# Counting the number of null values.
print('Counting Null values')
with pd.option_context('display.max_rows', None,):
   print(df.isna().sum())

# Duplicated Rows
print('\n'*2 + 'Duplicated rows: ' + str(df.duplicated().sum()))

# Unique Values per column. 
print('\n' + 'UNIQUE DATA VALUES PER COLUMN')
with pd.option_context('display.max_rows', None,):
   print(df.nunique())

# Describing the numerical columns.
print('\n'*2 + 'Dataframe Description: ' + '\n'*2 + str(df.describe().T))
# Out:
# Shape of the NM EV Data: (70406, 65)
#
#
# DATAFRAME INFORMATION
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 70406 entries, 0 to 70405
# Data columns (total 65 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   Fuel Type Code                    70406 non-null  object
#  1   Station Name                      70406 non-null  object
#  2   Street Address                    70405 non-null  object
#  3   Intersection Directions           4493 non-null   object
#  4   City                              70406 non-null  object
#  5   State                             70406 non-null  object
#  6   ZIP                               70405 non-null  object
#  7   Plus4                             0 non-null      float64
#  8   Station Phone                     65204 non-null  object
#  9   Status Code                       70406 non-null  object
#  10  Expected Date                     1218 non-null   object
#  11  Groups With Access Code           70406 non-null  object
#  12  Access Days Time                  66628 non-null  object
#  13  Cards Accepted                    11289 non-null  object
#  14  BD Blends                         1217 non-null   object
#  15  NG Fill Type Code                 1603 non-null   object
#  16  NG PSI                            1597 non-null   object
#  17  EV Level1 EVSE Num                286 non-null    float64
#  18  EV Level2 EVSE Num                54144 non-null  float64
#  19  EV DC Fast Count                  8307 non-null   float64
#  20  EV Other Info                     49 non-null     object
#  21  EV Network                        60907 non-null  object
#  22  EV Network Web                    50305 non-null  object
#  23  Geocode Status                    70391 non-null  object
#  24  Latitude                          70406 non-null  float64
#  25  Longitude                         70406 non-null  float64
#  26  Date Last Confirmed               70188 non-null  object
#  27  ID                                70406 non-null  int64
#  28  Updated At                        70406 non-null  object
#  29  Owner Type Code                   30190 non-null  object
#  30  Federal Agency ID                 955 non-null    float64
#  31  Federal Agency Name               955 non-null    object
#  32  Open Date                         69310 non-null  object
#  33  Hydrogen Status Link              83 non-null     object
#  34  NG Vehicle Class                  1780 non-null   object
#  35  LPG Primary                       1867 non-null   object
#  36  E85 Blender Pump                  4508 non-null   object
#  37  EV Connector Types                60690 non-null  object
#  38  Country                           70406 non-null  object
#  39  Intersection Directions (French)  188 non-null    object
#  40  Access Days Time (French)         6591 non-null   object
#  41  BD Blends (French)                2 non-null      object
#  42  Groups With Access Code (French)  70406 non-null  object
#  43  Hydrogen Is Retail                117 non-null    object
#  44  Access Code                       70406 non-null  object
#  45  Access Detail Code                7423 non-null   object
#  46  Federal Agency Code               955 non-null    object
#  47  Facility Type                     27665 non-null  object
#  48  CNG Dispenser Num                 1039 non-null   float64
#  49  CNG On-Site Renewable Source      716 non-null    object
#  50  CNG Total Compression Capacity    708 non-null    float64
#  51  CNG Storage Capacity              357 non-null    float64
#  52  LNG On-Site Renewable Source      62 non-null     object
#  53  E85 Other Ethanol Blends          1458 non-null   object
#  54  EV Pricing                        16961 non-null  object
#  55  EV Pricing (French)               2032 non-null   object
#  56  LPG Nozzle Types                  1826 non-null   object
#  57  Hydrogen Pressures                116 non-null    object
#  58  Hydrogen Standards                116 non-null    object
#  59  CNG Fill Type Code                1603 non-null   object
#  60  CNG PSI                           1597 non-null   object
#  61  CNG Vehicle Class                 1622 non-null   object
#  62  LNG Vehicle Class                 158 non-null    object
#  63  EV On-Site Renewable Source       370 non-null    object
#  64  Restricted Access                 53435 non-null  object
# dtypes: float64(10), int64(1), object(54)
# memory usage: 34.9+ MB
#
#
#
#
# Counting Null values
# Fuel Type Code                          0
# Station Name                            0
# Street Address                          1
# Intersection Directions             65913
# City                                    0
# State                                   0
# ZIP                                     1
# Plus4                               70406
# Station Phone                        5202
# Status Code                             0
# Expected Date                       69188
# Groups With Access Code                 0
# Access Days Time                     3778
# Cards Accepted                      59117
# BD Blends                           69189
# NG Fill Type Code                   68803
# NG PSI                              68809
# EV Level1 EVSE Num                  70120
# EV Level2 EVSE Num                  16262
# EV DC Fast Count                    62099
# EV Other Info                       70357
# EV Network                           9499
# EV Network Web                      20101
# Geocode Status                         15
# Latitude                                0
# Longitude                               0
# Date Last Confirmed                   218
# ID                                      0
# Updated At                              0
# Owner Type Code                     40216
# Federal Agency ID                   69451
# Federal Agency Name                 69451
# Open Date                            1096
# Hydrogen Status Link                70323
# NG Vehicle Class                    68626
# LPG Primary                         68539
# E85 Blender Pump                    65898
# EV Connector Types                   9716
# Country                                 0
# Intersection Directions (French)    70218
# Access Days Time (French)           63815
# BD Blends (French)                  70404
# Groups With Access Code (French)        0
# Hydrogen Is Retail                  70289
# Access Code                             0
# Access Detail Code                  62983
# Federal Agency Code                 69451
# Facility Type                       42741
# CNG Dispenser Num                   69367
# CNG On-Site Renewable Source        69690
# CNG Total Compression Capacity      69698
# CNG Storage Capacity                70049
# LNG On-Site Renewable Source        70344
# E85 Other Ethanol Blends            68948
# EV Pricing                          53445
# EV Pricing (French)                 68374
# LPG Nozzle Types                    68580
# Hydrogen Pressures                  70290
# Hydrogen Standards                  70290
# CNG Fill Type Code                  68803
# CNG PSI                             68809
# CNG Vehicle Class                   68784
# LNG Vehicle Class                   70248
# EV On-Site Renewable Source         70036
# Restricted Access                   16971
# dtype: int64
#
#
# Duplicated rows: 0
#
# UNIQUE DATA VALUES PER COLUMN
# Fuel Type Code                          7
# Station Name                        62835
# Street Address                      52295
# Intersection Directions              4035
# City                                 8278
# State                                  65
# ZIP                                 22182
# Plus4                                   0
# Station Phone                       17059
# Status Code                             3
# Expected Date                         145
# Groups With Access Code                28
# Access Days Time                     2552
# Cards Accepted                        728
# BD Blends                              33
# NG Fill Type Code                       3
# NG PSI                                  5
# EV Level1 EVSE Num                     24
# EV Level2 EVSE Num                     63
# EV DC Fast Count                       32
# EV Other Info                           9
# EV Network                             34
# EV Network Web                         32
# Geocode Status                          7
# Latitude                            67078
# Longitude                           67388
# Date Last Confirmed                    92
# ID                                  70406
# Updated At                           4816
# Owner Type Code                         6
# Federal Agency ID                      26
# Federal Agency Name                    26
# Open Date                            3796
# Hydrogen Status Link                   82
# NG Vehicle Class                        3
# LPG Primary                             1
# E85 Blender Pump                        2
# EV Connector Types                     26
# Country                                 2
# Intersection Directions (French)      172
# Access Days Time (French)             755
# BD Blends (French)                      2
# Groups With Access Code (French)       28
# Hydrogen Is Retail                      1
# Access Code                             2
# Access Detail Code                      9
# Federal Agency Code                    26
# Facility Type                          62
# CNG Dispenser Num                      26
# CNG On-Site Renewable Source            5
# CNG Total Compression Capacity        213
# CNG Storage Capacity                  155
# LNG On-Site Renewable Source            1
# E85 Other Ethanol Blends               15
# EV Pricing                            749
# EV Pricing (French)                   140
# LPG Nozzle Types                        4
# Hydrogen Pressures                      2
# Hydrogen Standards                      2
# CNG Fill Type Code                      3
# CNG PSI                                 5
# CNG Vehicle Class                       3
# LNG Vehicle Class                       1
# EV On-Site Renewable Source             6
# Restricted Access                       2
# dtype: int64
#
#
# Dataframe Description:
#
#                                   count           mean           std  \
# Plus4                               0.0            NaN           NaN
# EV Level1 EVSE Num                286.0       3.461538      6.548356
# EV Level2 EVSE Num              54144.0       2.315289      3.157387
# EV DC Fast Count                 8307.0       3.576381      4.129470
# Latitude                        70406.0      38.929309      5.628458
# Longitude                       70406.0     -96.061447     19.545273
# ID                              70406.0  148730.326066  54261.672118
# Federal Agency ID                 955.0      13.905759      6.767439
# CNG Dispenser Num                1039.0       2.731473      8.333492
# CNG Total Compression Capacity    708.0     873.766949   1032.371466
# CNG Storage Capacity              357.0   47866.787115  54327.698853
#
#                                        min            25%            50%  \
# Plus4                                  NaN            NaN            NaN
# EV Level1 EVSE Num                1.000000       1.000000       1.000000
# EV Level2 EVSE Num                1.000000       2.000000       2.000000
# EV DC Fast Count                  1.000000       1.000000       2.000000
# Latitude                          0.000000      34.182981      39.105989
# Longitude                      -159.788556    -117.860563     -92.002897
# ID                               17.000000  113723.250000  165247.500000
# Federal Agency ID                 2.000000       8.000000      14.000000
# CNG Dispenser Num                 0.000000       1.000000       2.000000
# CNG Total Compression Capacity    2.000000     215.750000     632.000000
# CNG Storage Capacity              0.000000   30000.000000   36000.000000
#
#                                           75%            max
# Plus4                                     NaN            NaN
# EV Level1 EVSE Num                   2.000000      51.000000
# EV Level2 EVSE Num                   2.000000     311.000000
# EV DC Fast Count                     4.000000      56.000000
# Latitude                            42.702185      64.852466
# Longitude                          -78.881493      40.432278
# ID                              190653.750000  224382.000000
# Federal Agency ID                   17.000000      60.000000
# CNG Dispenser Num                    2.000000     202.000000
# CNG Total Compression Capacity    1100.000000   10620.000000
# CNG Storage Capacity             60000.000000  593136.000000

# %%
#Onsight renewable energy resources. 
print('EV On-Site Renewable Sources')
print(str(df['EV On-Site Renewable Source'].value_counts()) + '\n'*2)
print('Fuel Types')
print(str(df['Fuel Type Code'].value_counts()) + '\n'*2)

print('EV Pricing Per Visit')
with pd.option_context('display.max_rows', None,):
   print(df['EV Pricing'].value_counts())


# print(str(df['EV Pricing'].value_counts()))
# Out:
# EV On-Site Renewable Sources
# SOLAR         252
# NONE           73
# WIND           27
# HYDRO          14
# WASTEWATER      3
# LANDFILL        1
# Name: EV On-Site Renewable Source, dtype: int64
#
#
# Fuel Types
# ELEC    60907
# E85      4508
# LPG      1867
# CNG      1631
# BD       1218
# LNG       158
# HY        117
# Name: Fuel Type Code, dtype: int64
#
#
# EV Pricing Per Visit
# Free                                                                                                                                                                 10377
# $0.28 per kWh; $0.26 per minute above 60 kW and $0.13 per minute at or below 60 kW                                                                                    1155
# FREE                                                                                                                                                                  1122
# Level 2: $0.49 per kWh                                                                                                                                                 785
# Level 2: $0.59 per kWh                                                                                                                                                 303
# $2.00/Hr Parking Fee                                                                                                                                                   222
# Level 2: $0.03 per 30 seconds                                                                                                                                          199
# $0.44 per minute above 60 kW and $0.22 per minute at or below 60 kW                                                                                                    123
# $1.00/Hr Parking Fee                                                                                                                                                   100
# $1 initiation fee + $0.32 per minute                                                                                                                                    88
# $1.50 per hour                                                                                                                                                          69
# $1.50/Hr Parking Fee                                                                                                                                                    67
# L2: $1.50 per hour; DC Fast: $15 per hour                                                                                                                               62
# $0.00-$1.00/Hr Variable Parking Fee                                                                                                                                     59
# $1.35/Hr Parking Fee                                                                                                                                                    55
# $0.00-$5.00/Hr Variable Parking Fee                                                                                                                                     52
# $1 per hour                                                                                                                                                             50
# $0.13 per kWh                                                                                                                                                           43
# $1.00-$5.00/Hr Variable Parking Fee                                                                                                                                     40
# $0.00-$2.00/Hr Variable Parking Fee                                                                                                                                     38
# Level 2: $0.55 per kWh                                                                                                                                                  37
# $1.00-$2.00/Hr Variable Parking Fee                                                                                                                                     35
# $0.21 per minute                                                                                                                                                        35
# Free, only while shopping in Publix                                                                                                                                     33
# DC Fast: $7.50 per session or $19.99 for monthly plan, Level 2: $4 per session or $19.99 for monthly plan                                                               30
# $0.20/kWh Energy Fee                                                                                                                                                    29
# $0.45 per kWh from 4pm-9pm; $0.30 per kWh at all other times                                                                                                            28
# $0.33 per minute                                                                                                                                                        28
# $0.30 per minute                                                                                                                                                        25
# Level 2: $4 per session or $19.99 for monthly plan, DC Fast: $7.50 per session or $19.99 for monthly plan                                                               24
# $0.00-$10.00/Hr Variable Parking Fee                                                                                                                                    22
# Level 2: $0.69 per kWh                                                                                                                                                  20
# $2 per hour                                                                                                                                                             20
# $1 per session                                                                                                                                                          19
# $0.30 per kWh                                                                                                                                                           18
# Free; parking fee                                                                                                                                                       17
# $0.07 per kWh                                                                                                                                                           17
# $0.25 per kWh                                                                                                                                                           17
# $1 per hour; Maximum payment of $3                                                                                                                                      16
# Level 2: $1 initiation fee + $1.15 per hour; DC Fast $1 initiation fee + $0.32 per minute                                                                               16
# $0.30/kWh Energy Fee                                                                                                                                                    15
# $0.24 per kWh                                                                                                                                                           14
# $3 per hour                                                                                                                                                             14
# $0.25/kWh Energy Fee                                                                                                                                                    14
# Level 2: $0.35 per kWh                                                                                                                                                  13
# $1.00-$25.00/Hr Variable Parking Fee                                                                                                                                    12
# Variable parking fee                                                                                                                                                    12
# FREE for 30 Minutes                                                                                                                                                     11
# $2.00-$5.00/Hr Variable Parking Fee                                                                                                                                     11
# Free; parking fee required                                                                                                                                              10
# $0.27 per minute                                                                                                                                                        10
# $9 parking fee                                                                                                                                                          10
# $0.00-$20.00/Hr Variable Parking Fee                                                                                                                                    10
# $0.20 per kWh                                                                                                                                                           10
# $2.00-$6.00/Hr Variable Parking Fee                                                                                                                                     10
# $0.30 per min                                                                                                                                                            9
# $0.15 per kWh                                                                                                                                                            9
# L2: Free; DC Fast: $0.33 per minute                                                                                                                                      9
# $1.00-$3.00/Hr Variable Parking Fee                                                                                                                                      8
# $0.50-$0.75/Hr Variable Parking Fee                                                                                                                                      8
# $0.00-$25.00/Hr Variable Parking Fee                                                                                                                                     8
# $2.00-$4.00/Hr Variable Parking Fee                                                                                                                                      8
# $0.42 per kWh                                                                                                                                                            8
# Level 2: $9.99 per session                                                                                                                                               8
# FREE for 30 minutes                                                                                                                                                      8
# $0.00-$1.35/Hr Variable Parking Fee                                                                                                                                      8
# $0.00-$4.00/Hr Variable Parking Fee                                                                                                                                      8
# Parking fee                                                                                                                                                              8
# $0.49 per kWh                                                                                                                                                            8
# $1.50-$5.00/Hr Variable Parking Fee                                                                                                                                      8
# Level 2: $0.21 per kWh                                                                                                                                                   8
# $2.50/Hr Parking Fee                                                                                                                                                     8
# $5 per session                                                                                                                                                           8
# $0.50/Hr Parking Fee                                                                                                                                                     8
# $1.25 per hour                                                                                                                                                           7
# FREE for first 30 minutes                                                                                                                                                7
# $1.25-$5.00/Hr Variable Parking Fee                                                                                                                                      7
# $0.10 per kWh                                                                                                                                                            7
# $0.30 per kWh; $0.45 per kWh from 4pm-9pm                                                                                                                                7
# Level 2: $0.25 per kWh                                                                                                                                                   7
# $0.10/kWh Energy Fee                                                                                                                                                     7
# Level 2: $0.99 per kWh                                                                                                                                                   7
# Level 2: $0.42 per kWh                                                                                                                                                   7
# $0.00-$5.00/Hr Variable Parking Fee, $0.15/kWh Energy Fee                                                                                                                7
# $5 per hour                                                                                                                                                              7
# Free; Parking fee                                                                                                                                                        7
# $0.29 per kWh                                                                                                                                                            7
# $1.25/Hr Parking Fee                                                                                                                                                     7
# $2 per hour parking fee; Maximum session time of 4 hours                                                                                                                 7
# $10 per session                                                                                                                                                          6
# $0.75 per hour                                                                                                                                                           6
# L2: $1 initiation fee + $1.15 per hour; DC: $1 initiation fee + $0.32 per minute                                                                                         6
# $2.00 per hour                                                                                                                                                           6
# $5.00/Hr Parking Fee , $0.20/kWh Energy Fee                                                                                                                              6
# $0.18 per hour                                                                                                                                                           6
# $0.12/kWh Energy Fee                                                                                                                                                     6
# $3.00/Hr Parking Fee                                                                                                                                                     6
# Level 2: $0.28 per kWh                                                                                                                                                   6
# $0.45 per kWh                                                                                                                                                            6
# Level 2: $0.39 per kWh                                                                                                                                                   6
# Free for guests                                                                                                                                                          6
# $0.20 per minute                                                                                                                                                         6
# $0.35 per kWh                                                                                                                                                            6
# Level 2: $0.2 per kWh                                                                                                                                                    6
# $0.00-$3.00/Hr Variable Parking Fee                                                                                                                                      6
# $7 per session                                                                                                                                                           5
# $2 per session                                                                                                                                                           5
# $0.50-$0.95/Hr Variable Parking Fee                                                                                                                                      5
# $1.75/Hr Parking Fee                                                                                                                                                     5
# $0.59 per kWh                                                                                                                                                            5
# $0.50 per kWh                                                                                                                                                            5
# $12 per hour                                                                                                                                                             5
# Level 2: $0.29 per kWh                                                                                                                                                   5
# $0.15/kWh Energy Fee                                                                                                                                                     5
# Level 2: $4 per session or $19.99 for monthly plan                                                                                                                       5
# $0.49 per kWH                                                                                                                                                            5
# Level 2: $0.3 per kWh                                                                                                                                                    5
# $2.00-$8.00/Hr Variable Parking Fee                                                                                                                                      5
# $0.23 per kWh                                                                                                                                                            5
# Level 2: $1 per hour; DC fast: $5 per hour                                                                                                                               5
# $0.18 per kWh                                                                                                                                                            5
# $0.00-$2.00/Hr Variable Parking Fee, $0.20/kWh Energy Fee                                                                                                                4
# Billed by time plugged in                                                                                                                                                4
# $1.00-$4.00/Hr Variable Parking Fee                                                                                                                                      4
# $1.25-$3.00/Hr Variable Parking Fee                                                                                                                                      4
# $0.00-$0.50/Hr Variable Parking Fee                                                                                                                                      4
# $2.00-$10.00/Hr Variable Parking Fee                                                                                                                                     4
# $0.00-$5.00/Hr Variable Parking Fee, $0.00-$0.25/kWh Variable Energy Fee                                                                                                 4
# $3.25 per kWh                                                                                                                                                            4
# $1.00-$20.00/Hr Variable Parking Fee                                                                                                                                     4
# $1.5 per hour                                                                                                                                                            4
# $2.00/kWh Energy Fee                                                                                                                                                     4
# $0.00-$3.00/Hr Variable Parking Fee, $0.30/kWh Energy Fee                                                                                                                4
# $1 per first and second half-hour parking fee; $1 per each additional hour parking fee                                                                                   4
# $1.50-$2.50/Hr Variable Parking Fee                                                                                                                                      4
# $0.50/kWh Energy Fee                                                                                                                                                     4
# $12.08 per hour                                                                                                                                                          4
# Level 2: $0.79 per kWh                                                                                                                                                   4
# $1.50-$10.00/Hr Variable Parking Fee                                                                                                                                     4
# $0.50 per hour                                                                                                                                                           4
# $0.00-$7.50/Hr Variable Parking Fee, $0.75/kWh Energy Fee                                                                                                                4
# $0.28/kWh Energy Fee                                                                                                                                                     4
# $0.00-$5.00/Hr Variable Parking Fee, $0.20/kWh Energy Fee                                                                                                                4
# $1.50-$2.00/Hr Variable Parking Fee                                                                                                                                      3
# $4 per hour                                                                                                                                                              3
# $3 per session                                                                                                                                                           3
# $0.00-$15.00/Hr Variable Parking Fee                                                                                                                                     3
# $0.29/kWh Energy Fee                                                                                                                                                     3
# $0.00-$25.00/Hr Variable Parking Fee, $0.00-$0.42/kWh Variable Energy Fee                                                                                                3
# $2.00-$5.00/Hr Variable Parking Fee, $0.20/kWh Energy Fee                                                                                                                3
# $1.00/Hr Parking Fee , $0.20/kWh Energy Fee                                                                                                                              3
# $2 service fee; $0.45 per kWh                                                                                                                                            3
# $2 per hour; Maximum session time of 4 hours                                                                                                                             3
# $0.10-$0.25/kWh Variable Energy Fee                                                                                                                                      3
# Free for customers                                                                                                                                                       3
# $2.50 per hour                                                                                                                                                           3
# Free; Variable parking fee                                                                                                                                               3
# $0.00-$5.00/Hr Variable Parking Fee, $0.25/kWh Energy Fee                                                                                                                3
# Free for first 30 minutes                                                                                                                                                3
# DC: $0.32 per kWh while charging + $12 per hour idle fee; L2: $0.28 per kWh + $2 per hour idle fee                                                                       3
# $0.75 per hour parking fee                                                                                                                                               3
# $4.17 per month through Austin Energy’s Plug-In EVerywhere℠ program                                                                                                      3
# $0.10 per kWh for staff; $0.20 per kWh for public                                                                                                                        3
# Free for tenant use;\r\n$5 per session for public                                                                                                                        3
# $0.20 per kWh; Minimum payment of $0.50                                                                                                                                  3
# $1 per hour for first four hours; $10 per hour thereafter                                                                                                                3
# $0.75-$3.00/Hr Variable Parking Fee                                                                                                                                      3
# $0.12 per kWh                                                                                                                                                            3
# $0.14 per kWh                                                                                                                                                            3
# Level 2: $0.29 per kWh; DC Fast: $0.49 per kWh                                                                                                                           3
# $1.00-$7.00/Hr Variable Parking Fee                                                                                                                                      3
# Minimum payment of $5; Maximum payment of $15; Maximum session time of 1 hour                                                                                            3
# $0.00-$1.50/Hr Variable Parking Fee                                                                                                                                      3
# $1.00/Hr Parking Fee , $0.25/kWh Energy Fee                                                                                                                              3
# Level 2: $0.2 per minute                                                                                                                                                 3
# $1.50-$3.00/Hr Variable Parking Fee                                                                                                                                      3
# $0.00-$4.00/Hr Variable Parking Fee, $0.25/kWh Energy Fee                                                                                                                3
# $15 per session                                                                                                                                                          3
# $1 per hour for first 3 hours, $6 per hour after                                                                                                                         3
# $0.10 per kWh; parking fee                                                                                                                                               3
# Parking fee required                                                                                                                                                     3
# $1 per hour; free for employees                                                                                                                                          2
# $1.20 per hour; $0.35 transaction fee                                                                                                                                    2
# L2: $1.50 per hour; DC: $0.35 per minute                                                                                                                                 2
# $2.00-$5.00/Hr Variable Parking Fee, $0.10/kWh Energy Fee                                                                                                                2
# $1.00 per hour                                                                                                                                                           2
# $5.00-$12.00/Hr Variable Parking Fee                                                                                                                                     2
# $2.00-$3.00/Hr Variable Parking Fee                                                                                                                                      2
# $0.40 per kWh                                                                                                                                                            2
# $1 per half hour parking fee, Maximum payment of $16                                                                                                                     2
# $0.37/Hr Parking Fee                                                                                                                                                     2
# $4.00/Hr Parking Fee                                                                                                                                                     2
# $1.50 per hour for general public, $1 per hour for NAU faculty, staff, and students                                                                                      2
# Free for 30 Minutes                                                                                                                                                      2
# $1.50/Hr Parking Fee , $0.25/kWh Energy Fee                                                                                                                              2
# $1.25-$4.00/Hr Variable Parking Fee                                                                                                                                      2
# $6.50 per hour                                                                                                                                                           2
# Level 2: $0.45 per kWh                                                                                                                                                   2
# $0.00-$2.00/Hr Variable Parking Fee, $0.13/kWh Energy Fee                                                                                                                2
# $1.49/Hr Parking Fee                                                                                                                                                     2
# $.30 per kWh                                                                                                                                                             2
# $1 initiation fee + $1.15 per hour                                                                                                                                       2
# $0.00-$1.00/Hr Variable Parking Fee, $0.15/kWh Energy Fee                                                                                                                2
# $5 per session for non-guests                                                                                                                                            2
# $1 per hour parking fee                                                                                                                                                  2
# $0.45/kWh Energy Fee                                                                                                                                                     2
# $2.20 per hour                                                                                                                                                           2
# $0.06/kWh Energy Fee                                                                                                                                                     2
# Donations accepted                                                                                                                                                       2
# $0.00-$1.00/Hr Variable Parking Fee, $0.20/kWh Energy Fee                                                                                                                2
# $6 per session                                                                                                                                                           2
# $0.18/kWh Energy Fee                                                                                                                                                     2
# Level 2: $0.14 per minute                                                                                                                                                2
# $1.75-$5.00/Hr Variable Parking Fee                                                                                                                                      2
# $1.35/Hr Parking Fee , $0.28/kWh Energy Fee                                                                                                                              2
# Variable price                                                                                                                                                           2
# $1.25-$3.50/Hr Variable Parking Fee                                                                                                                                      2
# $0.24/kWh Energy Fee                                                                                                                                                     2
# $1.50/kWh Energy Fee                                                                                                                                                     2
# Free; pay to park                                                                                                                                                        2
# $1.70/Hr Parking Fee                                                                                                                                                     2
# $0.00-$10.00/Hr Variable Parking Fee, $0.25/kWh Energy Fee                                                                                                               2
# $1.50-$25.00/Hr Variable Parking Fee                                                                                                                                     2
# $0.00-$1.00/Hr Variable Parking Fee, $0.25/kWh Energy Fee                                                                                                                2
# Free for guests; $10 for non-guests                                                                                                                                      2
# Variable fee                                                                                                                                                             2
# Level 2: $3.0 per hour                                                                                                                                                   2
# $0.50 fee; $0.21 per minute                                                                                                                                              2
# $1.00/Hr Parking Fee , $0.12/kWh Energy Fee                                                                                                                              2
# Variable prices                                                                                                                                                          2
# $2.00/Hr Parking Fee , $0.20/kWh Energy Fee                                                                                                                              2
# $1.50/Hr Parking Fee , $0.15/kWh Energy Fee                                                                                                                              2
# $0.49/kWh Energy Fee                                                                                                                                                     2
# $0.40/Hr Parking Fee                                                                                                                                                     2
# $1.00-$10.00/Hr Variable Parking Fee                                                                                                                                     2
# $1.00-$2.00/Hr Variable Parking Fee, $0.15/kWh Energy Fee                                                                                                                2
# Level 2: $0.18 per kWh                                                                                                                                                   2
# $23 early bird (before 9am), $30 after, regardless of charging time. Pay at garage office.                                                                               2
# DC Fast: $7.50 per session or $19.99 for monthly plan                                                                                                                    2
# $0.00-$6.00/Hr Variable Parking Fee                                                                                                                                      2
# $0.00-$0.25/kWh Variable Energy Fee                                                                                                                                      2
# Free; donations accepted                                                                                                                                                 2
# $1.00-$15.00/Hr Variable Parking Fee                                                                                                                                     2
# $0.13/kWh Energy Fee                                                                                                                                                     2
# Free but access controlled                                                                                                                                               2
# $0.00-$4.00/Hr Variable Parking Fee, $0.00-$0.15/kWh Variable Energy Fee                                                                                                 2
# Free; donations encouraged                                                                                                                                               2
# $2 per hour parking fee                                                                                                                                                  2
# $10 parking fee                                                                                                                                                          2
# $2.00/Hr Parking Fee , $0.16/kWh Energy Fee                                                                                                                              2
# $1.00/Hr Parking Fee , $0.10/kWh Energy Fee                                                                                                                              2
# $20 per hour                                                                                                                                                             2
# Free for 30 minutes                                                                                                                                                      2
# $0.35/kWh Energy Fee                                                                                                                                                     2
# Free; variable parking fee                                                                                                                                               2
# Free; pay garage                                                                                                                                                         2
# Level 2: $0.08 per minute                                                                                                                                                2
# $1.00/kWh Energy Fee                                                                                                                                                     2
# $0.00-$1.00/Hr Variable Parking Fee, $0.17/kWh Energy Fee                                                                                                                2
# Free; Pay to park                                                                                                                                                        2
# $0.00-$4.00/Hr Variable Parking Fee, $0.00-$1.00/kWh Variable Energy Fee                                                                                                 2
# $0.11 per kWh                                                                                                                                                            2
# $2.50 per session                                                                                                                                                        2
# $0.00-$2.00/Hr Variable Parking Fee, $0.16/kWh Energy Fee                                                                                                                2
# Free with parking fee                                                                                                                                                    2
# By kWh                                                                                                                                                                   1
# $1.00-$6.00/Hr Variable Parking Fee                                                                                                                                      1
# Free; parking garage fees                                                                                                                                                1
# $3 per hour or garage rate                                                                                                                                               1
# DC: $5 initiation fee + $0.30 per minute; L2: Free                                                                                                                       1
# $3.00-$5.00/Hr Variable Parking Fee                                                                                                                                      1
# $1 per hour; 4 hour limit                                                                                                                                                1
# $3 per month                                                                                                                                                             1
# $0.00-$15.00/Hr Variable Parking Fee, $0.10-$0.21/kWh Variable Energy Fee                                                                                                1
# Free; $21 per day parking fee                                                                                                                                            1
# $.30/Min for DCFC, Free for Level 2                                                                                                                                      1
# $25 parking fee for non-guests                                                                                                                                           1
# $10.00-$20.00/Hr Variable Parking Fee                                                                                                                                    1
# ...
# $1/hour                                                                                                                                                                  1
# Free for guests; $10 per session for nonguests                                                                                                                           1
# $0.32/kWh Energy Fee                                                                                                                                                     1
# Level 2: $9.99 per 0 seconds                                                                                                                                             1
# Free during week day; $6.00 holidays and weekends                                                                                                                        1
# $0.50/hr + $0.10/kWh + $1.00/session                                                                                                                                     1
# $5 parking fee                                                                                                                                                           1
# $1 per hour + $1 to start                                                                                                                                                1
# $1.80/Hr Parking Fee                                                                                                                                                     1
# $0.20/Hr Parking Fee                                                                                                                                                     1
# $5 per 4 hour session                                                                                                                                                    1
# Free with attendence to gardens. Access code required from reception.                                                                                                    1
# $2 for 30 mins/ $20 for all day                                                                                                                                          1
# $0.00-$2.00/Hr Variable Parking Fee, $0.10-$0.35/kWh Variable Energy Fee                                                                                                 1
# $2.00/Hr Parking Fee , $0.14/kWh Energy Fee                                                                                                                              1
# $2 per charge. Pay via Venmo: Jidgette-Vernick or Paypal: TeslaSolarRoof                                                                                                 1
# L2: Free                                                                                                                                                                 1
# free; parking fee required                                                                                                                                               1
# $0.20 per kW, $2.00 minimum                                                                                                                                              1
# $1.55/Hr Parking Fee                                                                                                                                                     1
# $2.00/Hr Parking Fee , $0.13/kWh Energy Fee                                                                                                                              1
# $1.00-$8.00/Hr Variable Parking Fee                                                                                                                                      1
# $10.00/Hr Parking Fee , $0.20/kWh Energy Fee                                                                                                                             1
# $1 per hour for public; free for employees                                                                                                                               1
# $0.25 per kWh; parking fee                                                                                                                                               1
# Free for guests; $5 per session for non-guests                                                                                                                           1
# $0.13 per kWh + $2hour                                                                                                                                                   1
# $1 per hour; free for customers                                                                                                                                          1
# $1.25 per hour + $1 transaction fee                                                                                                                                      1
# $0.35/Hr Parking Fee                                                                                                                                                     1
# Level 2: Free                                                                                                                                                            1
# $2 per charge; $.028 per kW                                                                                                                                              1
# $0.50/kWh first 4 hours;$1.50/hour after 4 hours\r\nMaximum charging fee: $10.00                                                                                         1
# Level 2: $0.05 per 30 seconds                                                                                                                                            1
# $5.00/Hr Parking Fee                                                                                                                                                     1
# $25 parking fee                                                                                                                                                          1
# $1.80/hr                                                                                                                                                                 1
# Free for guests; $2.50 per session for nonguests                                                                                                                         1
# $1.35 per hour                                                                                                                                                           1
# L2: Free; DCFC: Free for 30 minutes                                                                                                                                      1
# $6.50 per session                                                                                                                                                        1
# $7 per session; Free with electric vehicle license plate                                                                                                                 1
# $3.00-$4.00/Hr Variable Parking Fee, $0.59/kWh Energy Fee                                                                                                                1
# $0.86/kWh Energy Fee                                                                                                                                                     1
# $5 per charge for others, reception closes at 10 PM                                                                                                                      1
# $0.28-$0.38/kWh Variable Energy Fee                                                                                                                                      1
# $0.00-$8.00/Hr Variable Parking Fee                                                                                                                                      1
# $3.00/Hr Parking Fee , $0.92/kWh Energy Fee                                                                                                                              1
# Free for first 3 hours; $3 per hour after                                                                                                                                1
# Free with cost of parking                                                                                                                                                1
# $1 per hour; $5 per day                                                                                                                                                  1
# $1.00-$5.00/Hr Variable Parking Fee, $0.22/kWh Energy Fee                                                                                                                1
# Free after 4 PM; free following parking payment during hours of operation                                                                                                1
# $0.00-$4.00/Hr Variable Parking Fee, $0.00-$0.30/kWh Variable Energy Fee                                                                                                 1
# free                                                                                                                                                                     1
# Free; must pay park entrance fee                                                                                                                                         1
# Fee required                                                                                                                                                             1
# Donations appreciated                                                                                                                                                    1
# free for employees                                                                                                                                                       1
# $16 per day                                                                                                                                                              1
# $0.00-$1.00/Hr Variable Parking Fee, $0.00-$0.18/kWh Variable Energy Fee                                                                                                 1
# $0.90-$1.75/Hr Variable Parking Fee, $0.20/kWh Energy Fee                                                                                                                1
# $0.00-$2.00/Hr Variable Parking Fee, $0.75/kWh Energy Fee                                                                                                                1
# L2: $1.15 per hour; DC: $1 initiation fee + $0.32 per minute                                                                                                             1
# $0.45 per hour                                                                                                                                                           1
# $0.32 per kWh                                                                                                                                                            1
# $50 refundable deposit per session                                                                                                                                       1
# $1 per hour for first 2 hours, $5 per hour after                                                                                                                         1
# Level 2: $1.5 per hour                                                                                                                                                   1
# $2.00/Hr Parking Fee , $0.10/kWh Energy Fee                                                                                                                              1
# $0.75-$1.50/Hr Variable Parking Fee                                                                                                                                      1
# $0.48/kWh Energy Fee                                                                                                                                                     1
# $5.00-$15.00/Hr Variable Parking Fee                                                                                                                                     1
# $5 per hour for non-customers                                                                                                                                            1
# $1.00/Hr Parking Fee , $0.14/kWh Energy Fee                                                                                                                              1
# Free for guests; $15 for non-guests                                                                                                                                      1
# DC: per minute pricing; L2: Free                                                                                                                                         1
# $3 for first hour; then $5 per hour                                                                                                                                      1
# $12 per hour; $3 fee                                                                                                                                                     1
# $0.00-$4.00/Hr Variable Parking Fee, $0.15/kWh Energy Fee                                                                                                                1
# L2: $8 per session; Tesla: $10 per session                                                                                                                               1
# $3.50-$10.00/Hr Variable Parking Fee                                                                                                                                     1
# Level 2: $0.07 per minute                                                                                                                                                1
# $1.25 per 20 minutes                                                                                                                                                     1
# $1.00-$5.00/kWh Variable Energy Fee                                                                                                                                      1
# $0.39/Hr Parking Fee , $0.39/kWh Energy Fee                                                                                                                              1
# Free; Donations encouraged                                                                                                                                               1
# Free for guest; $15 per session for public                                                                                                                               1
# $0.15/Hr Parking Fee , $0.10/kWh Energy Fee                                                                                                                              1
# Level 2: free; DC fast: fee required                                                                                                                                     1
# $0.00-$0.75/Hr Variable Parking Fee, $0.09/kWh Energy Fee                                                                                                                1
# Free; park pass fee                                                                                                                                                      1
# Level 2: $0.32 per kWh                                                                                                                                                   1
# Name: EV Pricing, dtype: int64

# %% [markdown]
# # Data Visualisation

# %%
import seaborn as sns

for i in data.columns:
 plt.figure(figsize=(13,7))
 sns.histplot(data = df[i], kde=True, multiple='stack')
 plt.xticks(rotation=90)
 plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-62-a6422960ee7b> in <module>
#       5  sns.histplot(data = df[i], kde=True, multiple='stack')
#       6  plt.xticks(rotation=90)
# ----> 7  plt.show()
#
# ~\Anaconda\lib\site-packages\matplotlib\pyplot.py in show(*args, **kwargs)
#     351     """
#     352     _warn_if_gui_out_of_main_thread()
# --> 353     return _backend_mod.show(*args, **kwargs)
#     354
#     355
#
# ~\Anaconda\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      39     try:
#      40         for figure_manager in Gcf.get_all_fig_managers():
# ---> 41             display(
#      42                 figure_manager.canvas.figure,
#      43                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\Anaconda\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     311             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     312         else:
# --> 313             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     314             if not format_dict:
#     315                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\Anaconda\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\Anaconda\lib\site-packages\decorator.py in fun(*args, **kw)
#     229             if not kwsyntax:
#     230                 args, kw = fix(args, kw, sig)
# --> 231             return caller(func, *(extras + args), **kw)
#     232     fun.__name__ = func.__name__
#     233     fun.__doc__ = func.__doc__
#
# ~\Anaconda\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\Anaconda\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\Anaconda\lib\site-packages\IPython\core\pylabtools.py in <lambda>(fig)
#     246
#     247     if 'png' in formats:
# --> 248         png_formatter.for_type(Figure, lambda fig: print_figure(fig, 'png', **kwargs))
#     249     if 'retina' in formats or 'png2x' in formats:
#     250         png_formatter.for_type(Figure, lambda fig: retina_figure(fig, **kwargs))
#
# ~\Anaconda\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, **kwargs)
#     130         FigureCanvasBase(fig)
#     131
# --> 132     fig.canvas.print_figure(bytes_io, **kw)
#     133     data = bytes_io.getvalue()
#     134     if fmt == 'svg':
#
# ~\Anaconda\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2191                            else suppress())
#    2192                     with ctx:
# -> 2193                         self.figure.draw(renderer)
#    2194
#    2195                     bbox_inches = self.figure.get_tightbbox(
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda\lib\site-packages\matplotlib\figure.py in draw(self, renderer)
#    1861
#    1862             self.patch.draw(renderer)
# -> 1863             mimage._draw_list_compositing_images(
#    1864                 renderer, self, artists, self.suppressComposite)
#    1865
#
# ~\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\Anaconda\lib\site-packages\matplotlib\axes\_base.py in draw(self, renderer, inframe)
#    2745             renderer.stop_rasterizing()
#    2746
# -> 2747         mimage._draw_list_compositing_images(renderer, self, artists)
#    2748
#    2749         renderer.close_group('axes')
#
# ~\Anaconda\lib\site-packages\matplotlib\image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     129     if not_composite or not has_images:
#     130         for a in artists:
# --> 131             a.draw(renderer)
#     132     else:
#     133         # Composite any adjacent images together
#
# ~\Anaconda\lib\site-packages\matplotlib\artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      39                 renderer.start_filter()
#      40
# ---> 41             return draw(artist, renderer, *args, **kwargs)
#      42         finally:
#      43             if artist.get_agg_filter() is not None:
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in draw(self, renderer, *args, **kwargs)
#    1174         # the actual bbox
#    1175
# -> 1176         self._update_label_position(renderer)
#    1177
#    1178         self.label.draw(renderer)
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _update_label_position(self, renderer)
#    2059         # get bounding boxes for this axis and any siblings
#    2060         # that have been set by `fig.align_xlabels()`
# -> 2061         bboxes, bboxes2 = self._get_tick_boxes_siblings(renderer=renderer)
#    2062
#    2063         x, y = self.label.get_position()
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _get_tick_boxes_siblings(self, renderer)
#    2044         for nn, axx in enumerate(grp.get_siblings(self.axes)):
#    2045             ticks_to_draw = axx.xaxis._update_ticks()
# -> 2046             tlb, tlb2 = axx.xaxis._get_tick_bboxes(ticks_to_draw, renderer)
#    2047             bboxes.extend(tlb)
#    2048             bboxes2.extend(tlb2)
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda\lib\site-packages\matplotlib\axis.py in <listcomp>(.0)
#    1089     def _get_tick_bboxes(self, ticks, renderer):
#    1090         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1091         return ([tick.label1.get_window_extent(renderer)
#    1092                  for tick in ticks if tick.label1.get_visible()],
#    1093                 [tick.label2.get_window_extent(renderer)
#
# ~\Anaconda\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer, dpi)
#     900
#     901         with cbook._setattr_cm(self.figure, dpi=dpi):
# --> 902             bbox, info, descent = self._get_layout(self._renderer)
#     903             x, y = self.get_unitless_position()
#     904             x, y = self.get_transform().transform((x, y))
#
# ~\Anaconda\lib\site-packages\matplotlib\text.py in _get_layout(self, renderer)
#     293             clean_line, ismath = self._preprocess_math(line)
#     294             if clean_line:
# --> 295                 w, h, d = renderer.get_text_width_height_descent(
#     296                     clean_line, self._fontproperties, ismath=ismath)
#     297             else:
#
# ~\Anaconda\lib\site-packages\matplotlib\backends\backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     236         flags = get_hinting_flag()
#     237         font = self._get_agg_font(prop)
# --> 238         font.set_text(s, 0.0, flags=flags)
#     239         w, h = font.get_width_height()  # width and height of unrotated string
#     240         d = font.get_descent()
#
# KeyboardInterrupt:

# %% [markdown]
# # Importance of Features

# %% [markdown]
# This section will attempt to discover the importance of each feature in determining the pricing of charging an electric vehicle. Analyse the importance of features for predicting if charging the Electronic Vehicles is free at each particular charging station.

# %%
# Copy the data & perform train and test split
data1 = df.copy()
from sklearn.model_selection import train_test_split
Dtrain,Dtest = train_test_split(data1, test_size=0.3)

# %%
print('The shape of the training data:')
print(Dtrain.shape)
print('The shape of the test data:')
print(Dtest.shape)
# Out:
# The shape of the training data:
# (49284, 65)
# The shape of the test data:
# (21122, 65)

# %%
# Logistic Regression Approach
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score
import numpy as np

lambda_val = 0.1
#Initialize the Logitic regression model with l2 penalty
lr = LogisticRegression(C=1/lambda_val, penalty='l2')
lr.fit(Dtrain[predictors], Dtrain[response])
y_predict = lr.predict(Dtest[predictors])

#Evaluate our model
model_acc = accuracy_score(y_predict, Dtest[response])
print("Model Accuracy is: {}".format(model_acc))

print("Model Coeff: {}".format(np.append(lr.intercept_, lr.coef_)))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-65-038bccd0ea49> in <module>
#       7 #Initialize the Logitic regression model with l2 penalty
#       8 lr = LogisticRegression(C=1/lambda_val, penalty='l2')
# ----> 9 lr.fit(Dtrain[predictors], Dtrain[response])
#      10 y_predict = lr.predict(Dtest[predictors])
#      11
#
# NameError: name 'predictors' is not defined

# %%
def runLRmodel(trials, data, predictors, label, penalty_type, penalty_score):

   model_acc     = 0
   model_weights = np.zeros([1,9])

   for i in range(0,trials):
      Dtrain, Dtest = train_test_split(data, test_size=0.3)
      lr = LogisticRegression(C=1/penalty_score, penalty=penalty_type, solver='liblinear')
      lr.fit(Dtrain[predictors], Dtrain[label])
      y_predict = lr.predict(Dtest[predictors])
      model_acc += accuracy_score(y_predict, Dtest[label])
      model_weights += np.append(lr.intercept_, lr.coef_)

   model_acc /= trials
   model_weights /= trials

   return np.round(model_acc, decimals=2), np.round(model_weights,decimals=2)

# %%
lambda_vals = [.0001,.0003,.001,.003,.01,.03,.1,.3,1,3,5,10]
l2_acc = np.zeros(len(lambda_vals))
index = 0
#L2 regularization
for l in lambda_vals:
   l2_acc[index], w = runLRmodel(500,data1, predictors, 'class', 'l2', np.float(1))
   index += 1

print("Acc: {}".format(l2_acc))
# penalty at which validation accuracy is maximum
max_index_l2  = np.argmax(l2_acc)
best_lambda = lambda_vals[max_index_l2]
print("Best Lambda from L2: {}".format(best_lambda))

# %%
alpha_vals = [.0001,.0003,.001,.003,.01,.03,.1,.3,1,3,5,10]
l1_acc = np.zeros(len(alpha_vals))
index = 0
#L2 regularization
for l in alpha_vals:
   l1_acc[index], w = runLRmodel(500,data1, predictors, 'class', 'l1', np.float(l))
   index += 1

print("Acc: {}".format(l1_acc))
# penalty at which validation accuracy is maximum
max_index_l1  = np.argmax(l1_acc)
best_alpha = alpha_vals[max_index_l1]
print("Best Alpha from L1: {}".format(best_alpha))
