# %%
import pandas as pd
import seaborn as sb
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats

# reading the csv files 
data = pd.read_csv("https://raw.githubusercontent.com/Chameleon-company/EVCFLO/main/datasets/EVCS_in_New_York.csv")

   #Creating the heatmap for visualisation
plt.figure(figsize = (8,6))
sb.heatmap(data.isnull(), cbar=False , cmap = 'magma')

#look up the number of rows with NaN data
print("How many data with NaN values?")
print(data.isnull().sum())

#Dropping the missing rows.
df_dropped = data.dropna(how = 'any')

#using Z-score to get rid of the outliers
#from the output there is no outliers
df_new = data[(np.abs(stats.zscore(data.Plus4)) < 4000)]
# Out:
# How many data with NaN values?
# Fuel Type Code                0
# Station Name                  0
# Street Address                0
# Intersection Directions    2959
# City                          0
# State                         0
# ZIP                           0
# Plus4                      3076
# Station Phone                29
# Status Code                   0
# Expected Date              3076
# Groups With Access Code       0
# Access Days Time              2
# Cards Accepted             2766
# EV Level1 EVSE Num         3065
# EV Level2 EVSE Num          221
# EV DC Fast Count           2836
# EV Other Info              3075
# EV Network                    0
# EV Network Web              167
# Geocode Status                0
# Latitude                      0
# Longitude                     0
# Date Last Confirmed           7
# ID                            0
# Updated At                    0
# Owner Type Code            1867
# Federal Agency ID          3066
# ...

# %%
import numpy as np 
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
import statsmodels.api as sm

df= pd.read_csv("https://raw.githubusercontent.com/Chameleon-company/EVCFLO/main/datasets/EVCS_in_New_York.csv")

df.head()

#descriptive statistic of the data
df.describe()

#get the information of the data in each column
df.info()


a=np.arange(1,104)

sb.pairplot(df,hue='Plus4')

#heatmap to show correlation of the data
ax= plt.figure(figsize=(15,8))
sb.heatmap(df.corr(),linewidths=1,linecolor='white',annot=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3076 entries, 0 to 3075
# Data columns (total 31 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Fuel Type Code           3076 non-null   object
#  1   Station Name             3076 non-null   object
#  2   Street Address           3076 non-null   object
#  3   Intersection Directions  117 non-null    object
#  4   City                     3076 non-null   object
#  5   State                    3076 non-null   object
#  6   ZIP                      3076 non-null   int64
#  7   Plus4                    0 non-null      float64
#  8   Station Phone            3047 non-null   object
#  9   Status Code              3076 non-null   object
#  10  Expected Date            0 non-null      float64
#  11  Groups With Access Code  3076 non-null   object
#  12  Access Days Time         3074 non-null   object
#  13  Cards Accepted           310 non-null    object
# ...
